# %% [markdown]
# ## Data Cleaning & Dataframe Prep
#
# This notebook handles the following tasks and prepares the data for the analysis.
# If you something off, please fix it and add it to here.
#
# Data Cleaning
#
# - Delete NaN entries.
# - Assign 0: Not Applicable to the Empirical Novelty that has been chosen as "Not Applicaple". We have observed that this occurs when reviewers think empirical novelty is not applicaple to a paper, which can be a theoretical one for instance. When calculating the mean of this, please do not include 0 entries.
# - Ethics Flags include data which says both NO. and Yes, ... All of the contradictory entries included explanations, so we have accepted them as Yes.
# - Delete reviews submitted after the deadline
#
# Data Preparation
#
# - Statistics related to each reviewer is calculated for each paper.
# - These statics are: std, mean, diff(max_score-min_score)
#
# ### Resulting datasets
#
# - review_df_clean -> reviewer per row cleaned data
# - paper_df -> per paper dataframe, statistics are calculated such as mean, std, variance, max_min difference etc.
# - df -> basic dataset

# %%
import pandas as pd 
import numpy as np
import re
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

file_name = "../data/ICLR.cc-2023-Conference.csv"
df = pd.read_csv(file_name)

# %%
df.columns = df.columns.str.replace("recommendation", "score", regex=False)

# %% [markdown]
# ### Dataframe 1: Reviewers as rows

# %%
# Instead of one row per paper, arrange data to have one reviewer per row.

reviewer_feature_cols = [col.split('reviewer1_')[1] for col in df.columns if col.startswith('reviewer1')]
for i in reviewer_feature_cols:
    print(i)
reviewer_cols = [col for col in df.columns for i in range(1, 5) if col.startswith('reviewer' + str(i) + '_')]
non_reviewer_cols = [col for col in df.columns if col not in reviewer_cols]


df['paper_id'] = np.arange(len(df))
review_df = pd.DataFrame(columns=['paper_id', 'reviewer', 'reviewer_score', 'reviewer_confidence', 'reviewer_summary_of_the_paper', 'reviewer_strength_and_weaknesses', 'reviewer_clarity_quality_novelty_and_reproducibility', 'reviewer_summary_of_the_review', 'reviewer_correctness', 'reviewer_technical_novelty_and_significance', 'reviewer_empirical_novelty_and_significance', 'reviewer_flag_for_ethics_review', 'reviewer_length', 'reviewer_cdate', 'reviewer_tmdate', 'title', 'keywords', 'TL;DR', 'abstract', 'cdate', 'tmdate', 'decision'])
for idx, row in df.iterrows():
    for i in range(1, 5):
        dict_ = {}
        for col in reviewer_feature_cols:
            dict_['reviewer'] = i
            dict_['reviewer' + '_' + col] = row['reviewer' + str(i) + '_' + col]
        for col in non_reviewer_cols:
            dict_[col] = row[col]
        dict_['paper_id'] = row['paper_id']
        review_df.loc[len(review_df)] = dict_

df.head()
# Out:
# score
# confidence
# summary_of_the_paper
# strength_and_weaknesses
# clarity_quality_novelty_and_reproducibility
# summary_of_the_review
# correctness
# technical_novelty_and_significance
# empirical_novelty_and_significance
# flag_for_ethics_review
# length
# cdate
# tmdate
#                                                title  \
# 0  Guiding Safe Exploration with Weakest Precondi...
# 1  An Adaptive Entropy-Regularization Framework f...
# 2      AutoSparse: Towards Automated Sparse Training
# 3  Sampling is as easy as learning the score: the...
# 4  RoCourseNet: Distributionally Robust Training ...
#
#                                             keywords  \
# 0  reinforcement learning; safe learning; safe ex...
# 1  Multi-Agent Reinforcement Learning; Entropy Re...
# 2           sparsity; sparse training; deep learning
# 3  diffusion models; score-based generative model...
# 4  Counterfactual Explanation; Algorithmic Recour...
#
#                                                TL;DR  \
# 0  We use an online, weakest-precondition-based a...
# 1  This paper proposes  an adaptive entropy-regul...
# 2                                                NaN
# 3  We prove that given an L2-accurate score estim...
# 4                                                NaN
#
#                                             abstract                cdate  \
# 0  In reinforcement learning for safety-critical ...  2022-09-22 14:36:24
# 1  In this paper, we propose an adaptive entropy-...  2022-09-22 14:33:17
# 2  Sparse training is emerging as a promising ave...  2022-09-22 14:32:39
# 3  We provide theoretical convergence guarantees ...  2022-09-22 14:40:10
# 4  Counterfactual (CF) explanations for machine l...  2022-09-22 14:38:43
#
#                 tmdate                               reviewer1_score  \
# 0  2024-11-25 10:13:40  6: marginally above the acceptance threshold
# 1  2023-02-14 00:28:54                    3: reject, not good enough
# 2  2023-02-14 00:29:06  5: marginally below the acceptance threshold
# 3  2023-02-14 00:27:00                         8: accept, good paper
# 4  2024-11-25 10:12:40                    3: reject, not good enough
#
#                                 reviewer1_confidence  \
# 0  4: You are confident in your assessment, but n...
# 1  4: You are confident in your assessment, but n...
# 2  4: You are confident in your assessment, but n...
# 3  4: You are confident in your assessment, but n...
# 4  4: You are confident in your assessment, but n...
#
#                       reviewer1_summary_of_the_paper  \
# 0  This paper deals with safe exploration in rein...
# 1  This paper presents an MARL algorithm to adpat...
# 2  This paper first introduces a technique called...
# 3  This paper examines the convergence of SGMs un...
# 4  This submission proposed an approach to solvin...
#
#                    reviewer1_strength_and_weaknesses  \
# 0  ### Strength\n- Interesting and importance pro...
# 1  ### Strengths\n\n1. This paper studies adaptiv...
# 2  Strengths:\n\n- Provided intuitive examples an...
# 3  Strength:\n\n- The presentation is clear.\n\n-...
# 4  Strength:\n\n1. The paper is easy to follow.\n...
#
#   reviewer1_clarity_quality_novelty_and_reproducibility  \
# 0  ### Clarity\nThis paper is mostly well-written...
# 1  The Clarity of this paper can definitely be im...
# 2  Clarity & reproducibility:\n- Some hyperparame...
# 3  The presentation is clear except for a few min...
# 4  The quality of this submission is not high. Th...
#
#                      reviewer1_summary_of_the_review  \
# 0  Though this paper presents a new, promising me...
# 1  This paper studies adaptive entropy regulariza...
# 2  Overall I appreciate the authors' work, and it...
# 3  This paper provides several convergence result...
# 4  I suggest rejecting this paper. For details, p...
#
#                                reviewer1_correctness  \
# 0  2: Several of the paper’s claims are incorrect...
# 1  2: Several of the paper’s claims are incorrect...
# 2  3: Some of the paper’s claims have minor issue...
# 3  3: Some of the paper’s claims have minor issue...
# 4  3: Some of the paper’s claims have minor issue...
#
#         reviewer1_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  2: The contributions are only marginally signi...
# 2  3: The contributions are significant and somew...
# 3  3: The contributions are significant and somew...
# 4  2: The contributions are only marginally signi...
#
#         reviewer1_empirical_novelty_and_significance  \
# 0  2: The contributions are only marginally signi...
# 1  2: The contributions are only marginally signi...
# 2  2: The contributions are only marginally signi...
# 3                                     Not applicable
# 4  2: The contributions are only marginally signi...
#
#   reviewer1_flag_for_ethics_review  reviewer1_length      reviewer1_cdate  \
# 0                              NO.              3055  2022-10-20 09:40:48
# 1                              NO.              4790  2022-10-20 13:11:43
# 2                              NO.              3918  2022-10-24 09:15:54
# 3                              NO.              4594  2022-10-21 20:21:21
# 4                              NO.              3630  2022-10-16 18:53:54
#
#       reviewer1_tmdate                               reviewer2_score  \
# 0  2022-11-23 10:36:28                         8: accept, good paper
# 1  2022-10-20 13:11:43                         8: accept, good paper
# 2  2022-10-24 09:15:54  6: marginally above the acceptance threshold
# 3  2022-11-27 18:11:29                         8: accept, good paper
# 4  2022-10-16 18:53:54                    3: reject, not good enough
#
#                                 reviewer2_confidence  \
# 0  3: You are fairly confident in your assessment...
# 1  4: You are confident in your assessment, but n...
# 2  5: You are absolutely certain about your asses...
# 3  3: You are fairly confident in your assessment...
# 4  3: You are fairly confident in your assessment...
#
#                       reviewer2_summary_of_the_paper  \
# 0  This paper adapts ideas from formal program an...
# 1  This paper proposes an adaptive entropy-regula...
# 2  The paper introduces Gradient Annealing (GA) a...
# 3  This work provides a convergence guarantee for...
# 4  The authors propose combining adversarial trai...
#
#                    reviewer2_strength_and_weaknesses  \
# 0  # Strengths\n\nThe technique is well motivated...
# 1  - Strengths:\n\t- The proposed framework is we...
# 2  I will go sequentially for both strengths and ...
# 3  Strengths:\n- Well-written and presented clear...
# 4  Strengths: \n- The method is fairly straightfo...
#
#   reviewer2_clarity_quality_novelty_and_reproducibility  \
# 0  The technique and motivation are clearly commu...
# 1  The paper has good clarity overall. Most of th...
# 2  The code snippets are provided in the appendix...
# 3  This paper is exceptionally clear and well-wri...
# 4  - This paper is quite clearly written, and the...
#
#                      reviewer2_summary_of_the_review  \
# 0  The paper contributes a novel algorithm for cr...
# 1  I like the main idea of ADER. It seems to prov...
# 2  While the idea of GA alleviates some of the is...
# 3  While this is a very technical paper, there is...
# 4  This work is of high technical quality and the...
#
#                                reviewer2_correctness  \
# 0  4: All of the claims and statements are well-s...
# 1  4: All of the claims and statements are well-s...
# 2  3: Some of the paper’s claims have minor issue...
# 3  4: All of the claims and statements are well-s...
# 4  4: All of the claims and statements are well-s...
#
#         reviewer2_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  4: The contributions are significant, and do n...
# 2  2: The contributions are only marginally signi...
# 3  4: The contributions are significant, and do n...
# 4  2: The contributions are only marginally signi...
#
#         reviewer2_empirical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  3: The contributions are significant and somew...
# 2  2: The contributions are only marginally signi...
# 3  4: The contributions are significant, and do n...
# 4  2: The contributions are only marginally signi...
#
#   reviewer2_flag_for_ethics_review  reviewer2_length      reviewer2_cdate  \
# 0                              NO.              3272  2022-10-25 00:42:31
# 1                              NO.              4824  2022-10-23 18:43:07
# 2                              NO.              4825  2022-10-27 02:33:37
# 3                              NO.              1575  2022-10-24 02:13:45
# 4                              NO.              2097  2022-10-24 04:04:13
#
#       reviewer2_tmdate                               reviewer3_score  \
# 0  2022-10-25 00:42:31  6: marginally above the acceptance threshold
# 1  2022-10-23 18:43:07  6: marginally above the acceptance threshold
# 2  2022-12-05 02:01:28                    3: reject, not good enough
# 3  2022-10-24 02:13:45                         8: accept, good paper
# 4  2022-10-24 04:04:13                    3: reject, not good enough
#
#                                 reviewer3_confidence  \
# 0  3: You are fairly confident in your assessment...
# 1  3: You are fairly confident in your assessment...
# 2  5: You are absolutely certain about your asses...
# 3  3: You are fairly confident in your assessment...
# 4  4: You are confident in your assessment, but n...
#
#                       reviewer3_summary_of_the_paper  \
# 0  The paper proposes a method for safe reinforce...
# 1  This paper aims to solve the exploration-explo...
# 2  This paper proposes gradient annealing method ...
# 3  This paper provides convergence bounds for sco...
# 4  The paper tackles the problem of generating co...
#
#                    reviewer3_strength_and_weaknesses  \
# 0  + The approach reduces the number of safety vi...
# 1  - The strength of the paper comes from the ide...
# 2  Strengths\n\n1. This paper investigates differ...
# 3  Strength: The results are pretty impressive gi...
# 4  ## Strenghts:\n\nThe authors are effective in ...
#
#   reviewer3_clarity_quality_novelty_and_reproducibility  \
# 0  The paper is overall well written and presente...
# 1  This paper is well-written with high clarity. ...
# 2  To sum up, the clarity and quality of this pap...
# 3                 Clearly written and novel results.
# 4  The paper explanation of the method is clear w...
#
#                      reviewer3_summary_of_the_review  \
# 0  The paper builds on previous work on safe rein...
# 1  I would give marginally above the acceptance t...
# 2   I think this paper needs major revision, both...
# 3  The paper reads well and presents important re...
# 4  While the paper has some strengths, as highlig...
#
#                                reviewer3_correctness  \
# 0  4: All of the claims and statements are well-s...
# 1  4: All of the claims and statements are well-s...
# 2  3: Some of the paper’s claims have minor issue...
# 3  4: All of the claims and statements are well-s...
# 4  3: Some of the paper’s claims have minor issue...
#
#         reviewer3_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  3: The contributions are significant and somew...
# 2  1: The contributions are neither significant n...
# 3  4: The contributions are significant, and do n...
# 4  2: The contributions are only marginally signi...
#
#         reviewer3_empirical_novelty_and_significance  \
# 0  2: The contributions are only marginally signi...
# 1  2: The contributions are only marginally signi...
# 2  1: The contributions are neither significant n...
# 3  4: The contributions are significant, and do n...
# 4                                     Not applicable
#
#   reviewer3_flag_for_ethics_review  reviewer3_length      reviewer3_cdate  \
# 0                              NO.            1508.0  2022-10-26 00:04:46
# 1                              NO.            2716.0  2022-10-24 22:26:06
# 2                              NO.            2958.0  2022-10-27 05:32:06
# 3                              NO.            2385.0  2022-10-25 14:35:52
# 4                              NO.            3586.0  2022-10-24 23:15:45
#
#       reviewer3_tmdate                               reviewer4_score  \
# 0  2022-10-26 00:04:46  6: marginally above the acceptance threshold
# 1  2022-10-24 22:26:06                                           NaN
# 2  2022-10-27 05:32:06                    3: reject, not good enough
# 3  2022-10-25 14:45:19                         8: accept, good paper
# 4  2022-10-24 23:15:45  6: marginally above the acceptance threshold
#
#                                 reviewer4_confidence  \
# 0  4: You are confident in your assessment, but n...
# 1                                                NaN
# 2  5: You are absolutely certain about your asses...
# 3  3: You are fairly confident in your assessment...
# 4  4: You are confident in your assessment, but n...
#
#                       reviewer4_summary_of_the_paper  \
# 0  The paper proposes a safe RL algorithm, Symbol...
# 1                                                NaN
# 2  In this paper, the authors propose a new spars...
# 3  The paper proposes a theoretical analysis of S...
# 4  The paper proposes an architecture and a train...
#
#                    reviewer4_strength_and_weaknesses  \
# 0  Strengths:\n* SPICE’s use of formal methods pr...
# 1                                                NaN
# 2  Strength:\n1.\tThis paper is well written and ...
# 3  Despite the strong claims, the paper seems to ...
# 4  + The paper deals with a practical problem; ge...
#
#   reviewer4_clarity_quality_novelty_and_reproducibility  \
# 0  The paper is generally clear. I appreciate the...
# 1                                                NaN
# 2                  See the strength and weaknesses.
# 3  The paper is very clear, despite the complex s...
# 4  The paper is written clearly and is easy to fo...
#
#                      reviewer4_summary_of_the_review  \
# 0  I like the proposed approach and its associate...
# 1                                                NaN
# 2  1. The proposed method seems tricky and not el...
# 3  Overall I think the paper introduces very stro...
# 4  The paper solves an important problem. The exp...
#
#                                reviewer4_correctness  \
# 0  4: All of the claims and statements are well-s...
# 1                                                NaN
# 2  2: Several of the paper’s claims are incorrect...
# 3  3: Some of the paper’s claims have minor issue...
# 4  4: All of the claims and statements are well-s...
#
#         reviewer4_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1                                                NaN
# 2  2: The contributions are only marginally signi...
# 3  3: The contributions are significant and somew...
# 4  2: The contributions are only marginally signi...
#
#         reviewer4_empirical_novelty_and_significance  \
# 0  2: The contributions are only marginally signi...
# 1                                                NaN
# 2  1: The contributions are neither significant n...
# 3                                     Not applicable
# 4  2: The contributions are only marginally signi...
#
#   reviewer4_flag_for_ethics_review  reviewer4_length      reviewer4_cdate  \
# 0                              NO.            3082.0  2022-11-03 08:08:39
# 1                              NaN               NaN                  NaN
# 2                              NO.            2254.0  2022-10-27 20:14:54
# 3                              NO.            5316.0  2022-10-27 22:09:32
# 4                              NO.            2937.0  2022-10-29 20:23:57
#
#       reviewer4_tmdate                decision  paper_id
# 0  2022-12-14 03:46:36          Accept: poster         0
# 1                  NaN                  Reject         1
# 2  2022-10-27 20:14:54                  Reject         2
# 3  2022-10-27 22:09:32  Accept: notable-top-5%         3
# 4  2022-10-29 20:23:57                  Reject         4

# %% [markdown]
# ### Data prep: convert and simplify column values
#
# 1. Convert cdate to pandas datetime datatype.
# 2. Add time_to_deadline column which measures the time difference between the review submission and review deadline
# 3. To get the score part, remove the explanations from score columns such as recommendation.
# 3.5. If there are non-scored reviewers, assign them the avg score of the others
# 4. Add a is_high_variance column to detect high discrepancy reviews.
# 5. There are different acceptances, like top-5-notable etc. We just treat them as expected, so simply those explanations.

# %%
df['reviewer1_cdate'] = pd.to_datetime(df['reviewer1_cdate'])
df['reviewer2_cdate'] = pd.to_datetime(df['reviewer2_cdate'])
df['reviewer3_cdate'] = pd.to_datetime(df['reviewer3_cdate'])
df['reviewer4_cdate'] = pd.to_datetime(df['reviewer4_cdate'])

deadline = "2022-10-25 00:00:00"
df['reviewer1_time_to_deadline'] = pd.to_datetime(deadline) - df['reviewer1_cdate']
df['reviewer2_time_to_deadline'] = pd.to_datetime(deadline) - df['reviewer2_cdate']
df['reviewer3_time_to_deadline'] = pd.to_datetime(deadline) - df['reviewer3_cdate']
df['reviewer4_time_to_deadline'] = pd.to_datetime(deadline) - df['reviewer4_cdate']

df.dropna(subset=['reviewer1_cdate', 'reviewer2_cdate', 'reviewer3_cdate', 'reviewer4_cdate'], how='all', inplace=True)

def get_scores_from_str(x):
    if isinstance(x, str):
        return int(x.split(':')[0])
    else:
        return np.nan
    
df['reviewer1_score'] = df['reviewer1_score'].apply(lambda x: get_scores_from_str(x))
df['reviewer2_score'] = df['reviewer2_score'].apply(lambda x: get_scores_from_str(x))
df['reviewer3_score'] = df['reviewer3_score'].apply(lambda x: get_scores_from_str(x))
df['reviewer4_score'] = df['reviewer4_score'].apply(lambda x: get_scores_from_str(x))

df['max_score'] = df[['reviewer1_score', 'reviewer2_score', 'reviewer3_score', 'reviewer4_score']].max(axis=1)
df['min_score'] = df[['reviewer1_score', 'reviewer2_score', 'reviewer3_score', 'reviewer4_score']].min(axis=1)
df['max_min_score_diff'] = df['max_score'] - df['min_score']

df['is_high_variance'] = df['max_min_score_diff'] >= 4

df['decision'] = df['decision'].apply(lambda x: "Accept" if "accept" in x.lower() else "Reject")

df['max_score'] = df[['reviewer1_score', 'reviewer2_score', 'reviewer3_score', 'reviewer4_score']].max(axis=1)
df['min_score'] = df[['reviewer1_score', 'reviewer2_score', 'reviewer3_score', 'reviewer4_score']].min(axis=1)
df['max_min_score_diff'] = df['max_score'] - df['min_score']

df['is_high_variance'] = df['max_min_score_diff'] >= 4

df['decision'] = df['decision'].apply(lambda x: "Accept" if "accept" in x.lower() else "Reject")

# %% [markdown]
# Play with variables and check if the values are as expected:

# %%
pd.set_option('display.max_rows', 10)
df[df['decision'].eq("Accept") & df['is_high_variance']]
# Out:
#                                                   title  \
# 9     Improved Training of Physics-Informed Neural N...
# 32    PD-MORL: Preference-Driven Multi-Objective Rei...
# 33    CircNet: Meshing 3D Point Clouds with Circumce...
# 34    Semi-supervised learning with a principled lik...
# 37    Is Adversarial Training Really a Silver Bullet...
# ...                                                 ...
# 3678  DDM$^2$: Self-Supervised Diffusion MRI Denoisi...
# 3743  SeaFormer: Squeeze-enhanced Axial Transformer ...
# 3746  Neural Image-based Avatars: Generalizable Radi...
# 3752  Approximate Nearest Neighbor Search through Mo...
# 3760  Modeling Sequential Sentence Relation to Impro...
#
#                                                keywords  \
# 9     Physics-informed neural networks; electrical i...
# 32    multi-objective reinforcement learning; MORL; ...
# 33    Meshing; 3D Point Cloud; Point Cloud Triangula...
# 34    Bayesian deep learning; Bayesian neural networ...
# 37    Data poisoning; adversarial training; indiscri...
# ...                                                 ...
# 3678       Unsupervised MRI Denoising; Diffusion Models
# 3743                                                NaN
# 3746  Generalizable human radiance fields; Human per...
# 3752  Similarity Search; Nearest-Neighbor Search; Po...
# 3760                                                NaN
#
#                                                   TL;DR  \
# 9                                                   NaN
# 32    A novel approach that obtains a single policy ...
# 33    We present a deep neural architecture that det...
# 34    We develop Bayesian semi-supervised learning, ...
# 37    We propose an indiscriminative feature-based p...
# ...                                                 ...
# 3678                                                NaN
# 3743                                                NaN
# 3746                                                NaN
# 3752  Using modern error-correcting codes, we presen...
# 3760                                                NaN
#
#                                                abstract                cdate  \
# 9     Physics-informed neural networks (PINNs) are a...  2022-09-22 14:42:07
# 32    Multi-objective reinforcement learning (MORL) ...  2022-09-22 14:37:04
# 33    Reconstructing 3D point clouds into triangle m...  2022-09-22 14:34:26
# 34    We currently do not have an understanding of s...  2022-09-22 14:34:48
# 37    Indiscriminate data poisoning can decrease the...  2022-09-22 14:36:10
# ...                                                 ...                  ...
# 3678  Magnetic resonance imaging (MRI) is a common a...  2022-09-22 14:31:21
# 3743  Since the introduction of Vision Transformers,...  2022-09-22 14:32:03
# 3746  We present a method that enables synthesizing ...  2022-09-22 14:41:21
# 3752  A locality-sensitive hash (or LSH) is a functi...  2022-09-22 14:33:10
# 3760  Recently multi-lingual pre-trained language mo...  2022-09-22 14:33:02
#
#                    tmdate  reviewer1_score  \
# 9     2023-02-26 07:06:29               10
# 32    2023-03-02 03:46:32                8
# 33    2024-11-25 10:14:38                8
# 34    2023-02-21 09:35:10                5
# 37    2023-03-02 17:30:28                6
# ...                   ...              ...
# 3678  2024-11-25 10:16:17                1
# 3743  2024-11-25 10:15:52                8
# 3746  2024-11-25 10:11:30                8
# 3752  2023-02-14 10:50:31                6
# 3760  2023-03-02 06:12:41                6
#
#                                    reviewer1_confidence  \
# 9     4: You are confident in your assessment, but n...
# 32    3: You are fairly confident in your assessment...
# 33    4: You are confident in your assessment, but n...
# 34    4: You are confident in your assessment, but n...
# 37    4: You are confident in your assessment, but n...
# ...                                                 ...
# 3678  5: You are absolutely certain about your asses...
# 3743  2: You are willing to defend your assessment, ...
# 3746  3: You are fairly confident in your assessment...
# 3752  3: You are fairly confident in your assessment...
# 3760  4: You are confident in your assessment, but n...
#
#                          reviewer1_summary_of_the_paper  \
# 9     The manuscript is using PINN to solve the prob...
# 32    This work proposes an algorithm for solving mu...
# 33    This paper tackles the problem of point cloud ...
# 34    The authors consider the fact that our common ...
# 37    In this work the authors attack in models in t...
# ...                                                 ...
# 3678  The paper proposes a new method for denoising ...
# 3743  this paper presents SeaFormer: a new transform...
# 3746  The authors propose Neural Image-based Avatars...
# 3752  In this paper, the authors investigate a probl...
# 3760  The paper presents a contrastive learning appr...
#
#                       reviewer1_strength_and_weaknesses  \
# 9     This is an excellent paper. Introduction of th...
# 32    The main strengths of this paper:\n- Novel app...
# 33    Strength\n+ The formulation of the problem as ...
# 34    ## Strengths\nThe paper is well argued for and...
# 37    Strengths:\n* The method is novel and obtains ...
# ...                                                 ...
# 3678  Strengths\n\nThe proposed method makes use of ...
# 3743  Strength:\n- The proposed transformer is O(WH)...
# 3746  Main Strengths:\n- The method gathers two comp...
# 3752  The paper has the following strengths:\n\nS1. ...
# 3760  Strengths\n1. The paper is well-written and ex...
#
#      reviewer1_clarity_quality_novelty_and_reproducibility  \
# 9     High quality paper trying to stuff a lot of in...
# 32    Besides the main weakness described above, the...
# 33    Overall, this paper is clearly written and eas...
# 34    - Sec 2.2 uses `n` annotators and switches to ...
# 37    This paper is relatively well written other th...
# ...                                                 ...
# 3678  \nThe work is original but the paper lacks cla...
# 3743  This paper is clear, of good quality, with con...
# 3746  The paper is clear and technically sound. The ...
# 3752  This paper is well-written, and the figure mak...
# 3760  Clarity & Quality - The paper is clear and wel...
#
#                         reviewer1_summary_of_the_review  \
# 9                      Excellent and informative paper.
# 32    This work provides a strong contribution, back...
# 33    The idea of detecting circumcenters from point...
# 34    While the paper contains some interesting form...
# 37    The paper presents a new method that yields st...
# ...                                                 ...
# 3678  While the method is new, it has quite a few sh...
# 3743  The main contribution of the paper is a new at...
# 3746  The paper introduces a new approach to general...
# 3752  In summary, the authors did a good job by leve...
# 3760  A simple and easy-to-implement contrastive lea...
#
#                                   reviewer1_correctness  \
# 9     4: All of the claims and statements are well-s...
# 32    4: All of the claims and statements are well-s...
# 33    4: All of the claims and statements are well-s...
# 34    4: All of the claims and statements are well-s...
# 37    3: Some of the paper’s claims have minor issue...
# ...                                                 ...
# 3678  1: The main claims of the paper are incorrect ...
# 3743  4: All of the claims and statements are well-s...
# 3746  4: All of the claims and statements are well-s...
# 3752  3: Some of the paper’s claims have minor issue...
# 3760  3: Some of the paper’s claims have minor issue...
#
#            reviewer1_technical_novelty_and_significance  \
# 9     4: The contributions are significant, and do n...
# 32    3: The contributions are significant and somew...
# 33    3: The contributions are significant and somew...
# 34    2: The contributions are only marginally signi...
# 37    3: The contributions are significant and somew...
# ...                                                 ...
# 3678  2: The contributions are only marginally signi...
# 3743  3: The contributions are significant and somew...
# 3746  3: The contributions are significant and somew...
# 3752  3: The contributions are significant and somew...
# 3760  3: The contributions are significant and somew...
#
#            reviewer1_empirical_novelty_and_significance  \
# 9     4: The contributions are significant, and do n...
# 32    3: The contributions are significant and somew...
# 33    3: The contributions are significant and somew...
# 34    3: The contributions are significant and somew...
# 37    3: The contributions are significant and somew...
# ...                                                 ...
# 3678  2: The contributions are only marginally signi...
# 3743  3: The contributions are significant and somew...
# 3746  2: The contributions are only marginally signi...
# 3752  2: The contributions are only marginally signi...
# 3760  3: The contributions are significant and somew...
#
#      reviewer1_flag_for_ethics_review  reviewer1_length     reviewer1_cdate  \
# 9                                 NO.              1364 2022-10-24 18:52:56
# 32                                NO.              2262 2022-10-24 17:03:02
# 33                                NO.              2911 2022-10-20 13:13:09
# 34                                NO.              4268 2022-10-19 09:55:26
# 37                                NO.              2605 2022-10-24 09:11:14
# ...                               ...               ...                 ...
# 3678                              NO.              3044 2022-10-25 03:26:28
# 3743                              NO.              2599 2022-10-24 08:16:56
# 3746                              NO.              1917 2022-10-23 20:06:11
# 3752                              NO.              3630 2022-10-23 17:54:49
# 3760                              NO.              2805 2022-10-21 10:18:43
#
#          reviewer1_tmdate  reviewer2_score  \
# 9     2022-10-24 18:52:56                6
# 32    2022-10-24 17:03:02                8
# 33    2022-10-20 13:13:09                3
# 34    2022-10-19 09:55:26                8
# 37    2022-12-04 00:56:03                8
# ...                   ...              ...
# 3678  2022-10-25 03:26:28                6
# 3743  2022-10-24 08:16:56                3
# 3746  2022-10-23 20:06:11                3
# 3752  2022-10-23 17:55:16                8
# 3760  2022-10-21 10:18:43                6
#
#                                    reviewer2_confidence  \
# 9     3: You are fairly confident in your assessment...
# 32    4: You are confident in your assessment, but n...
# 33    4: You are confident in your assessment, but n...
# 34    4: You are confident in your assessment, but n...
# 37    4: You are confident in your assessment, but n...
# ...                                                 ...
# 3678  3: You are fairly confident in your assessment...
# 3743  4: You are confident in your assessment, but n...
# 3746  4: You are confident in your assessment, but n...
# 3752  4: You are confident in your assessment, but n...
# 3760  4: You are confident in your assessment, but n...
#
#                          reviewer2_summary_of_the_paper  \
# 9     This paper introduces the use of Bayesian appr...
# 32    The paper presents PD-MORL as a fascinating ne...
# 33    The paper proposes a method for point cloud tr...
# 34    The paper looks at the topic of semi-supervise...
# 37    This paper challenges the defense ability of a...
# ...                                                 ...
# 3678  This paper proposes a self-supervised denoisin...
# 3743  This paper presents a model called squeeze-enh...
# 3746  This paper aims to obtain Neural Image-based A...
# 3752  Takes the idea of polar codes (and polar codin...
# 3760  This paper introduces MSM, a hierarchical mult...
#
#                       reviewer2_strength_and_weaknesses  \
# 9     Strengths:\n1.\tThe proposed approach was demo...
# 32    The paper excels at explaining the problem, re...
# 33    Strengths\n* The paper is clearly written and ...
# 34    # Strengths\n\n* Highlights that curation (mul...
# 37    Strengths:\n- The setting of $\epsilon_{adv}\g...
# ...                                                 ...
# 3678  Strength:\n- Clear text and step-by-step descr...
# 3743  Strength:\n+ The squeeze axial attention saves...
# 3746  [Strengths]\n+ The motivation is well-written ...
# 3752  The strengths are that the proposal seems soun...
# 3760  Strength:\n- The paper is well organized and e...
#
#      reviewer2_clarity_quality_novelty_and_reproducibility  \
# 9     The paper is well written> the use of EB: prio...
# 32    The paper is mostly well written and clear, as...
# 33    The paper is mostly clearly written and easy t...
# 34    \n## Novelty\n\nI think there's plenty of cont...
# 37    - The paper is well-organized, and the propose...
# ...                                                 ...
# 3678  - The manuscript is written quite clearly. \n-...
# 3743  Clarity and Quality:\nThe paper is kind of eas...
# 3746  Clarity is not sufficient.\n\nThe framework of...
# 3752  While the paper says in part that it uses a st...
# 3760                                              Good.
#
#                         reviewer2_summary_of_the_review  \
# 9     The authors present an interesting approach fo...
# 32    This is a good paper that takes a clever, nove...
# 33    * The attached code does not include the code ...
# 34    Overall I like the core ideas here: the observ...
# 37    This paper establishes a new SOTA in degrading...
# ...                                                 ...
# 3678  I am not a super expert in diffusion model so ...
# 3743  This paper presents a model based on previous ...
# 3746  The primary concern of this paper is its limit...
# 3752  It seems to me the gains are sufficient to be ...
# 3760  The paper introduces a simple yet effective me...
#
#                                   reviewer2_correctness  \
# 9     3: Some of the paper’s claims have minor issue...
# 32    3: Some of the paper’s claims have minor issue...
# 33    2: Several of the paper’s claims are incorrect...
# 34    4: All of the claims and statements are well-s...
# 37    4: All of the claims and statements are well-s...
# ...                                                 ...
# 3678  3: Some of the paper’s claims have minor issue...
# 3743  3: Some of the paper’s claims have minor issue...
# 3746  3: Some of the paper’s claims have minor issue...
# 3752  4: All of the claims and statements are well-s...
# 3760  3: Some of the paper’s claims have minor issue...
#
#            reviewer2_technical_novelty_and_significance  \
# 9     3: The contributions are significant and somew...
# 32    4: The contributions are significant, and do n...
# 33    2: The contributions are only marginally signi...
# 34    3: The contributions are significant and somew...
# 37    3: The contributions are significant and somew...
# ...                                                 ...
# 3678  3: The contributions are significant and somew...
# 3743  2: The contributions are only marginally signi...
# 3746  2: The contributions are only marginally signi...
# 3752  4: The contributions are significant, and do n...
# 3760  3: The contributions are significant and somew...
#
#            reviewer2_empirical_novelty_and_significance  \
# 9     3: The contributions are significant and somew...
# 32    3: The contributions are significant and somew...
# 33    1: The contributions are neither significant n...
# 34    4: The contributions are significant, and do n...
# 37    3: The contributions are significant and somew...
# ...                                                 ...
# 3678                                     Not applicable
# 3743  2: The contributions are only marginally signi...
# 3746  2: The contributions are only marginally signi...
# 3752  4: The contributions are significant, and do n...
# 3760  2: The contributions are only marginally signi...
#
#      reviewer2_flag_for_ethics_review  reviewer2_length     reviewer2_cdate  \
# 9                                 NO.              2090 2022-10-24 22:45:31
# 32                                NO.              5597 2022-10-25 16:12:34
# 33                                NO.              4942 2022-10-22 15:41:11
# 34                                NO.              8203 2022-10-25 20:14:55
# 37                                NO.              3286 2022-10-24 17:35:04
# ...                               ...               ...                 ...
# 3678                              NO.              2071 2022-10-25 11:08:10
# 3743                              NO.              3097 2022-10-24 14:27:00
# 3746                              NO.              3961 2022-10-24 18:18:59
# 3752                              NO.              3706 2022-10-24 05:27:37
# 3760                              NO.              1556 2022-10-24 06:19:03
#
#          reviewer2_tmdate  reviewer3_score  \
# 9     2022-10-24 22:45:31              8.0
# 32    2022-11-28 23:01:55              5.0
# 33    2022-10-22 15:47:47              6.0
# 34    2022-11-19 04:42:51              3.0
# 37    2022-12-06 06:47:51             10.0
# ...                   ...              ...
# 3678  2022-10-25 11:08:56              6.0
# 3743  2022-10-24 14:27:00              8.0
# 3746  2022-10-24 18:18:59              6.0
# 3752  2022-10-24 05:27:37              6.0
# 3760  2022-10-24 06:19:03              8.0
#
#                                    reviewer3_confidence  \
# 9     3: You are fairly confident in your assessment...
# 32    3: You are fairly confident in your assessment...
# 33    2: You are willing to defend your assessment, ...
# 34    4: You are confident in your assessment, but n...
# 37    4: You are confident in your assessment, but n...
# ...                                                 ...
# 3678  4: You are confident in your assessment, but n...
# 3743  3: You are fairly confident in your assessment...
# 3746  4: You are confident in your assessment, but n...
# 3752  4: You are confident in your assessment, but n...
# 3760  3: You are fairly confident in your assessment...
#
#                          reviewer3_summary_of_the_paper  \
# 9     This paper proposes to incorporate energy-base...
# 32    This paper proposes PD-MORL, which extends Env...
# 33    The authors propose a method for creating a me...
# 34    The paper aims to formulate the low-density se...
# 37    The paper introduces a new approach, indiscrim...
# ...                                                 ...
# 3678  This paper provides an approach for self-super...
# 3743  The paper presented a new mobile ViT architect...
# 3746  This paper combines two rendering modules for ...
# 3752  This paper studies the approximate nearest nei...
# 3760  This work aims to improve the cross-lingual re...
#
#                       reviewer3_strength_and_weaknesses  \
# 9     Strength:\n- The paper is well written and org...
# 32    - Multi-objective reinforcement learning is an...
# 33    Strength:\n1) The paper is well-written and ea...
# 34    Strength: The likelihood for curated/uncurated...
# 37    **Strengths**\n\n- The paper is very clear and...
# ...                                                 ...
# 3678  Strengths:\n- The landscape of self-supervised...
# 3743  Strength:\n\n* The paper presents a new archit...
# 3746  **Strength**    \n* This method can achieve go...
# 3752  Strength:\n1. The combination of LSH and error...
# 3760  Overall this paper represents a great result. ...
#
#      reviewer3_clarity_quality_novelty_and_reproducibility  \
# 9     The paper is well written and organized. It pr...
# 32    The paper is clearly written. The major novelt...
# 33    The paper is easy to follow, and the writing i...
# 34    I feel that the paper has some reproducibility...
# 37    The paper is very clear and well written.  It ...
# ...                                                 ...
# 3678  The approach is clear and appears to be novel....
# 3743  The paper is written very clearly with enough ...
# 3746  * **Clarity**: Most contents are clear and eas...
# 3752  The proposed PCNN algorithm is easy to follow....
# 3760  This paper is easy to read and can be reproduced.
#
#                         reviewer3_summary_of_the_review  \
# 9     The paper studies an interesting problem and p...
# 32    This paper proposes a new method of MORL based...
# 33    The paper has some interesting contributions a...
# 34    Overall, I feel the paper is more like playing...
# 37    A very good and interesting paper, which moves...
# ...                                                 ...
# 3678  The authors develop a three-stage approach to ...
# 3743  The paper presented SeaFormer: a new mobile-Vi...
# 3746  Through extensive experiments, this paper show...
# 3752  This paper introduces the error-correction cod...
# 3760  Novel and effective approach, with a few minor...
#
#                                   reviewer3_correctness  \
# 9     3: Some of the paper’s claims have minor issue...
# 32    3: Some of the paper’s claims have minor issue...
# 33    4: All of the claims and statements are well-s...
# 34    4: All of the claims and statements are well-s...
# 37    4: All of the claims and statements are well-s...
# ...                                                 ...
# 3678  4: All of the claims and statements are well-s...
# 3743  3: Some of the paper’s claims have minor issue...
# 3746  3: Some of the paper’s claims have minor issue...
# 3752  3: Some of the paper’s claims have minor issue...
# 3760  3: Some of the paper’s claims have minor issue...
#
#            reviewer3_technical_novelty_and_significance  \
# 9     3: The contributions are significant and somew...
# 32    3: The contributions are significant and somew...
# 33    3: The contributions are significant and somew...
# 34    2: The contributions are only marginally signi...
# 37    4: The contributions are significant, and do n...
# ...                                                 ...
# 3678  3: The contributions are significant and somew...
# 3743  2: The contributions are only marginally signi...
# 3746  3: The contributions are significant and somew...
# 3752  4: The contributions are significant, and do n...
# 3760  3: The contributions are significant and somew...
#
#            reviewer3_empirical_novelty_and_significance  \
# 9     3: The contributions are significant and somew...
# 32    3: The contributions are significant and somew...
# 33    2: The contributions are only marginally signi...
# 34    2: The contributions are only marginally signi...
# 37    3: The contributions are significant and somew...
# ...                                                 ...
# 3678  3: The contributions are significant and somew...
# 3743  3: The contributions are significant and somew...
# 3746  3: The contributions are significant and somew...
# 3752  3: The contributions are significant and somew...
# 3760  3: The contributions are significant and somew...
#
#      reviewer3_flag_for_ethics_review  reviewer3_length     reviewer3_cdate  \
# 9                                 NO.            3781.0 2022-10-30 05:41:08
# 32                                NO.            2991.0 2022-10-28 00:04:28
# 33                                NO.            1644.0 2022-11-04 23:06:04
# 34                                NO.            2820.0 2022-10-25 23:11:45
# 37                                NO.            1791.0 2022-10-25 21:23:49
# ...                               ...               ...                 ...
# 3678                              NO.            4742.0 2022-11-01 04:32:07
# 3743                              NO.            2459.0 2022-10-25 03:43:25
# 3746                              NO.            3032.0 2022-10-24 18:41:50
# 3752                              NO.            2233.0 2022-10-25 03:02:02
# 3760                              NO.            2620.0 2022-10-26 01:55:37
#
#          reviewer3_tmdate  reviewer4_score  \
# 9     2022-12-08 21:57:39              NaN
# 32    2022-12-15 19:01:55              3.0
# 33    2022-11-04 23:33:05              6.0
# 34    2022-10-25 23:11:45              5.0
# 37    2022-10-25 21:23:49              6.0
# ...                   ...              ...
# 3678  2022-11-01 04:32:07              8.0
# 3743  2022-11-23 22:06:47              5.0
# 3746  2022-10-24 18:41:50              8.0
# 3752  2022-10-25 03:02:02              3.0
# 3760  2022-10-26 01:55:37              3.0
#
#                                    reviewer4_confidence  \
# 9                                                   NaN
# 32    3: You are fairly confident in your assessment...
# 33    3: You are fairly confident in your assessment...
# 34    4: You are confident in your assessment, but n...
# 37    5: You are absolutely certain about your asses...
# ...                                                 ...
# 3678  4: You are confident in your assessment, but n...
# 3743  4: You are confident in your assessment, but n...
# 3746  4: You are confident in your assessment, but n...
# 3752  2: You are willing to defend your assessment, ...
# 3760  5: You are absolutely certain about your asses...
#
#                          reviewer4_summary_of_the_paper  \
# 9                                                   NaN
# 32    In this paper, the authors propose a new multi...
# 33    The paper introduces a novel method to generat...
# 34    In this paper the authors have formulated Semi...
# 37    The authors propose a novel technique to poiso...
# ...                                                 ...
# 3678  The paper proposes a new method for the denois...
# 3743  The paper present an incremental improvement o...
# 3746  The paper presents a human full-body avatar mo...
# 3752  The paper proposes a locality sensitive hashin...
# 3760  This work proposes a new method for cross-ling...
#
#                       reviewer4_strength_and_weaknesses  \
# 9                                                   NaN
# 32    Strength: \nThe idea to align the preference v...
# 33    Strengths:-\n1. A novel method to generate  tr...
# 34    Strengths: The main idea of this paper is to d...
# 37    ### Pros:\n1) The attack is intuitive, and the...
# ...                                                 ...
# 3678  The article is interesting, inspiring and intr...
# 3743  Strengths:\n- The results show that the overal...
# 3746  Paper strengths:\n- The proposed method is nov...
# 3752  The paper does not prove any rigorous guarante...
# 3760  Strengths:\n- The idea of MSM is simple and ne...
#
#      reviewer4_clarity_quality_novelty_and_reproducibility  \
# 9                                                   NaN
# 32    Most of my clarity comments are in the above s...
# 33    1. Quality of results can be improved by provi...
# 34    Overall, the structure of the paper is organiz...
# 37    The writing is clear, the method is novel as f...
# ...                                                 ...
# 3678  The article presents novel content and is clea...
# 3743  The paper is fairly easy to follow, although t...
# 3746  The paper is clearly-written and shows high qu...
# 3752  The writeup is clear, but hard to evaluate lac...
# 3760  The paper will not have any major impact as it...
#
#                         reviewer4_summary_of_the_review  \
# 9                                                   NaN
# 32    Because of the important baseline results miss...
# 33    The paper introduces a novel method to generat...
# 34    I have gone through the paper more than once; ...
# 37    I find the work interesting and well motivated...
# ...                                                 ...
# 3678  The article tackles a challenging problem. It ...
# 3743  There are some compelling experiments show tha...
# 3746  Overall speaking I think this is a solid paper...
# 3752  It's an interesting idea, but its validation i...
# 3760  The paper lacks strong baselines, shows only p...
#
#                                   reviewer4_correctness  \
# 9                                                   NaN
# 32    3: Some of the paper’s claims have minor issue...
# 33    4: All of the claims and statements are well-s...
# 34    3: Some of the paper’s claims have minor issue...
# 37    3: Some of the paper’s claims have minor issue...
# ...                                                 ...
# 3678  4: All of the claims and statements are well-s...
# 3743  3: Some of the paper’s claims have minor issue...
# 3746  4: All of the claims and statements are well-s...
# 3752  4: All of the claims and statements are well-s...
# 3760  2: Several of the paper’s claims are incorrect...
#
#            reviewer4_technical_novelty_and_significance  \
# 9                                                   NaN
# 32    2: The contributions are only marginally signi...
# 33    3: The contributions are significant and somew...
# 34    2: The contributions are only marginally signi...
# 37    3: The contributions are significant and somew...
# ...                                                 ...
# 3678  3: The contributions are significant and somew...
# 3743  2: The contributions are only marginally signi...
# 3746  3: The contributions are significant and somew...
# 3752  2: The contributions are only marginally signi...
# 3760  2: The contributions are only marginally signi...
#
#            reviewer4_empirical_novelty_and_significance  \
# 9                                                   NaN
# 32    2: The contributions are only marginally signi...
# 33    3: The contributions are significant and somew...
# 34    2: The contributions are only marginally signi...
# 37    4: The contributions are significant, and do n...
# ...                                                 ...
# 3678  4: The contributions are significant, and do n...
# 3743  2: The contributions are only marginally signi...
# 3746  4: The contributions are significant, and do n...
# 3752  2: The contributions are only marginally signi...
# 3760  2: The contributions are only marginally signi...
#
#      reviewer4_flag_for_ethics_review  reviewer4_length     reviewer4_cdate  \
# 9                                 NaN               NaN                 NaT
# 32                                NO.            2667.0 2022-11-02 19:06:49
# 33                                NO.            3701.0 2022-11-07 00:33:07
# 34                                NO.            3853.0 2022-10-28 04:31:38
# 37                                NO.            3887.0 2022-10-28 02:57:31
# ...                               ...               ...                 ...
# 3678                              NO.            6108.0 2022-11-01 13:53:36
# 3743                              NO.            4328.0 2022-10-25 11:54:51
# 3746                              NO.            1588.0 2022-10-25 11:28:04
# 3752                              NO.             681.0 2022-11-04 21:09:04
# 3760                              NO.            4108.0 2022-10-27 13:06:06
#
#          reviewer4_tmdate decision  paper_id reviewer1_time_to_deadline  \
# 9                     NaN   Accept         9            0 days 05:07:04
# 32    2022-11-02 19:15:05   Accept        32            0 days 06:56:58
# 33    2022-11-07 00:33:07   Accept        33            4 days 10:46:51
# 34    2022-10-28 04:31:38   Accept        34            5 days 14:04:34
# 37    2022-12-09 21:01:51   Accept        37            0 days 14:48:46
# ...                   ...      ...       ...                        ...
# 3678  2022-11-01 13:53:36   Accept      3678          -1 days +20:33:32
# 3743  2022-10-25 11:54:51   Accept      3743            0 days 15:43:04
# 3746  2022-10-25 11:28:04   Accept      3746            1 days 03:53:49
# 3752  2022-11-04 21:09:04   Accept      3752            1 days 06:05:11
# 3760  2022-10-27 13:06:06   Accept      3760            3 days 13:41:17
#
#      reviewer2_time_to_deadline reviewer3_time_to_deadline  \
# 9               0 days 01:14:29          -6 days +18:18:52
# 32            -1 days +07:47:26          -4 days +23:55:32
# 33              2 days 08:18:49         -11 days +00:53:56
# 34            -1 days +03:45:05          -1 days +00:48:15
# 37              0 days 06:24:56          -1 days +02:36:11
# ...                         ...                        ...
# 3678          -1 days +12:51:50          -8 days +19:27:53
# 3743            0 days 09:33:00          -1 days +20:16:35
# 3746            0 days 05:41:01            0 days 05:18:10
# 3752            0 days 18:32:23          -1 days +20:57:58
# 3760            0 days 17:40:57          -2 days +22:04:23
#
#      reviewer4_time_to_deadline  max_score  min_score  max_min_score_diff  \
# 9                           NaT       10.0        6.0                 4.0
# 32            -9 days +04:53:11        8.0        3.0                 5.0
# 33           -14 days +23:26:53        8.0        3.0                 5.0
# 34            -4 days +19:28:22        8.0        3.0                 5.0
# 37            -4 days +21:02:29       10.0        6.0                 4.0
# ...                         ...        ...        ...                 ...
# 3678          -8 days +10:06:24        8.0        1.0                 7.0
# 3743          -1 days +12:05:09        8.0        3.0                 5.0
# 3746          -1 days +12:31:56        8.0        3.0                 5.0
# 3752         -11 days +02:50:56        8.0        3.0                 5.0
# 3760          -3 days +10:53:54        8.0        3.0                 5.0
#
#       is_high_variance
# 9                 True
# 32                True
# 33                True
# 34                True
# 37                True
# ...                ...
# 3678              True
# 3743              True
# 3746              True
# 3752              True
# 3760              True
#
# [200 rows x 68 columns]

# %%
df[['reviewer1_score', 'reviewer2_score', 'reviewer3_score', 'reviewer4_score']]
# Out:
#       reviewer1_score  reviewer2_score  reviewer3_score  reviewer4_score
# 0                   6                8              6.0              6.0
# 1                   3                8              6.0              NaN
# 2                   5                6              3.0              3.0
# 3                   8                8              8.0              8.0
# 4                   3                3              3.0              6.0
# ...               ...              ...              ...              ...
# 3791                3                3              5.0              NaN
# 3792                1                6              6.0              3.0
# 3793                6                6              8.0              6.0
# 3794                6                3              3.0              3.0
# 3795                6                5              6.0              NaN
#
# [3796 rows x 4 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# 1. Clean reviews submitted after the deadline

# %%
review_df['reviewer_cdate'] = pd.to_datetime(review_df['reviewer_cdate'])
review_df_clean = review_df
# review_df_clean = review_df[review_df['reviewer_cdate'] < pd.to_datetime('2022-11-05 01:00:00')]
review_df_clean.dropna(subset=['reviewer_cdate'], inplace=True)

# %% [markdown]
# 2. Treat contradictiory ethis flags as Yes, because all of them include explanation.

# %%
review_df_clean.value_counts('reviewer_flag_for_ethics_review')
review_df_clean['reviewer_flag_for_ethics_review'] = review_df_clean['reviewer_flag_for_ethics_review'].apply(lambda x: 1 if 'yes' in str(x).lower() else 0)

# %% [markdown]
# 3. Assign 0 to Not applicaple papers for Empirical Novelty and Significance. These are generally treated as theoretical papers by the reviewers.

# %%
print(review_df_clean['reviewer_empirical_novelty_and_significance'].value_counts())
review_df_clean['reviewer_empirical_novelty_and_significance'] = review_df_clean['reviewer_empirical_novelty_and_significance'].apply(lambda x: "0: Not Applicable" if x == "Not applicable" else x)
review_df_clean['reviewer_empirical_novelty_and_significance'].value_counts()

review_df_clean.reset_index(drop=True, inplace=True)
# Out:
# reviewer_empirical_novelty_and_significance
# 3: The contributions are significant and somewhat new. Aspects of the contributions exist in prior work.    5938
# 2: The contributions are only marginally significant or novel.                                              5332
# Not applicable                                                                                              1087
# 4: The contributions are significant, and do not exist in prior works.                                      1028
# 1: The contributions are neither significant nor novel.                                                      629
# Name: count, dtype: int64

# %% [markdown]
# 4. Add time_to_deadline column

# %%
review_df_clean['time_to_deadline'] = pd.to_datetime(deadline) - review_df_clean['reviewer_cdate']

# %% [markdown]
# 5. Convert string numbers to integers.

# %%
review_df_clean['review_confidence'] = review_df_clean['reviewer_confidence'].apply(lambda x: x.split(':')[0].strip() if pd.notnull(x) else x).astype(int)
review_df_clean.drop(columns=['reviewer_confidence'], inplace=True)

review_df_clean['review_score'] = review_df_clean['reviewer_score'].apply(lambda x: x.split(':')[0].strip() if pd.notnull(x) else x).astype(int)
review_df_clean.drop(columns=['reviewer_score'], inplace=True)

review_df_clean['review_correctness'] = review_df_clean['reviewer_correctness'].apply(lambda x: x.split(':')[0].strip() if pd.notnull(x) else x).astype(int)
review_df_clean.drop(columns=['reviewer_correctness'], inplace=True)

review_df_clean['review_technical_novelty_and_significance'] = review_df_clean['reviewer_technical_novelty_and_significance'].apply(lambda x: x.split(':')[0].strip() if pd.notnull(x) else x).astype(int)
review_df_clean.drop(columns=['reviewer_technical_novelty_and_significance'], inplace=True)

review_df_clean['review_empirical_novelty_and_significance'] = review_df_clean['reviewer_empirical_novelty_and_significance'].apply(lambda x: x.split(':')[0].strip() if pd.notnull(x) else x).astype(int)
review_df_clean.drop(columns=['reviewer_empirical_novelty_and_significance'], inplace=True)

# %% [markdown]
# 6. Make all decisions have only "Accept"
# 7. Add high_variance information by joining on paper_id

# %%
review_df_clean['decision'] = review_df_clean['decision'].apply(lambda x: "Accept" if "accept" in x.lower() else "Reject")
review_df_clean = pd.merge(review_df_clean, df[['paper_id', 'is_high_variance']], on='paper_id', how='right')

# %% [markdown]
# ## Reviewer Dataset is completed

# %% [markdown]
# ### Dataframe 2: Papers as rows and reviewer statistics per paper

# %% [markdown]
# Use aggregation functions to calculate statistics per paper.
# - If you want to add a statistic or change one, add it to the lists next to the column names.

# %%
paper_df = review_df_clean.groupby('paper_id').agg({'time_to_deadline': ['std', 'mean'], 
                                                    'review_confidence': ['std', 'mean'],
                                                    'review_score': ['std', 'mean', 'max', 'min'],
                                                    'review_correctness': ['std', 'mean'],
                                                    'review_technical_novelty_and_significance': ['std', 'mean'],
                                                    'review_empirical_novelty_and_significance': ['std', 'mean'],
                                                    'reviewer': 'count',
                                                    'decision': 'first'}).reset_index()

paper_df["reviewer1_score"] = df["reviewer1_score"] 
paper_df["reviewer2_score"] = df["reviewer2_score"] 
paper_df["reviewer3_score"] = df["reviewer3_score"] 
paper_df["reviewer4_score"] = df["reviewer4_score"]

# %%
pd.set_option('display.max_columns', None)
paper_df
# Out:
#      paper_id          time_to_deadline                            \
#                                     std                      mean
# 0           0 5 days 19:16:10.689828726         -2 days +13:20:49
# 1           1 2 days 06:32:55.872867145 1 days 21:53:01.333333333
# 2           2 1 days 12:54:38.117582429  -2 days +08:35:52.250000
# 3           3 2 days 13:20:58.514324593    0 days 03:09:52.500000
# 4           4 5 days 09:23:30.024963235    1 days 01:20:32.750000
# ...       ...                       ...                       ...
# 3791     3791 5 days 23:13:08.435799653 5 days 10:16:41.666666666
# 3792     3792 4 days 09:28:45.175281084    0 days 21:56:18.250000
# 3793     3793 1 days 20:41:21.379731310    0 days 19:54:33.750000
# 3794     3794 3 days 09:33:53.422118322  -3 days +03:57:49.750000
# 3795     3795 7 days 04:45:12.891550738           0 days 05:42:36
#
#      review_confidence           review_score                    \
#                    std      mean          std      mean max min
# 0             0.577350  3.500000     1.000000  6.500000   8   6
# 1             0.577350  3.666667     2.516611  5.666667   8   3
# 2             0.500000  4.750000     1.500000  4.250000   6   3
# 3             0.500000  3.250000     0.000000  8.000000   8   8
# 4             0.500000  3.750000     1.500000  3.750000   6   3
# ...                ...       ...          ...       ...  ..  ..
# 3791          0.000000  4.000000     1.154701  3.666667   5   3
# 3792          0.816497  3.000000     2.449490  4.000000   6   1
# 3793          0.577350  3.500000     1.000000  6.500000   8   6
# 3794          0.000000  4.000000     1.500000  3.750000   6   3
# 3795          0.000000  4.000000     0.577350  5.666667   6   5
#
#      review_correctness           review_technical_novelty_and_significance  \
#                     std      mean                                       std
# 0              1.000000  3.500000                                  0.000000
# 1              1.154701  3.333333                                  1.000000
# 2              0.500000  2.750000                                  0.816497
# 3              0.577350  3.500000                                  0.577350
# 4              0.577350  3.500000                                  0.000000
# ...                 ...       ...                                       ...
# 3791           0.577350  3.333333                                  0.577350
# 3792           1.290994  2.500000                                  0.500000
# 3793           0.577350  3.500000                                  0.500000
# 3794           0.816497  3.000000                                  0.577350
# 3795           0.577350  2.666667                                  0.577350
#
#                review_empirical_novelty_and_significance           reviewer  \
#           mean                                       std      mean    count
# 0     3.000000                                  0.500000  2.250000        4
# 1     3.000000                                  0.577350  2.333333        3
# 2     2.000000                                  0.577350  1.500000        4
# 3     3.500000                                  2.309401  2.000000        4
# 4     2.000000                                  1.000000  1.500000        4
# ...        ...                                       ...       ...      ...
# 3791  2.666667                                  1.154701  0.666667        3
# 3792  2.750000                                  1.000000  0.500000        4
# 3793  2.250000                                  1.414214  2.000000        4
# 3794  2.500000                                  0.577350  2.500000        4
# 3795  2.666667                                  0.577350  2.666667        3
#
#      decision reviewer1_score reviewer2_score reviewer3_score reviewer4_score
#         first
# 0      Accept               6               8             6.0             6.0
# 1      Reject               3               8             6.0             NaN
# 2      Reject               5               6             3.0             3.0
# 3      Accept               8               8             8.0             8.0
# 4      Reject               3               3             3.0             6.0
# ...       ...             ...             ...             ...             ...
# 3791   Reject               3               3             5.0             NaN
# 3792   Reject               1               6             6.0             3.0
# 3793   Accept               6               6             8.0             6.0
# 3794   Reject               6               3             3.0             3.0
# 3795   Reject               6               5             6.0             NaN
#
# [3796 rows x 21 columns]

# %% [markdown]
# Add max-min difference column. This is our most basic metric for measuring discrepancy.

# %%
paper_df['review_score', 'max_min_diff'] = paper_df['review_score', 'max'] - paper_df['review_score', 'min']

# %% [markdown]
# Add high discrepancy papers.

# %%
paper_df['is_high_discrepancy'] = (paper_df['review_score', 'max_min_diff'] >= 4).astype(int)

# %% [markdown]
# ## Paper Dataset is completed

# %%
print("See the portion of papers accepted and rejected and has high discrepancy.")
print(paper_df.groupby(('decision', 'first'))['is_high_discrepancy'].mean())
# Out:
# See the portion of papers accepted and rejected and has high discrepancy.
# (decision, first)
# Accept    0.127146
# Reject    0.185335
# Name: is_high_discrepancy, dtype: float64

# %% [markdown]
# # Review Submission Time vs. Discrepancy Analysis

# %%
def custom_idx_min_time(row: pd.Series):
    min_val = row[['reviewer1_time_to_deadline', 'reviewer2_time_to_deadline', 'reviewer3_time_to_deadline', 'reviewer4_time_to_deadline']].min()
    min_val_str = ""
    for i in range(1, 5):
        if row['reviewer' + str(i) + '_time_to_deadline'] == min_val:
            min_val_str += str(i)

    return min_val_str

def custom_idx_min_rec(row: pd.Series):
    min_val = row[['reviewer1_score', 'reviewer2_score', 'reviewer3_score', 'reviewer4_score']].min()
    min_val_str = ""
    for i in range(1, 5):
        if row['reviewer' + str(i) + '_score'] == min_val:
            min_val_str += str(i)

    return min_val_str

def custom_idx_max(row: pd.Series):
    max_val = row[['reviewer1_score', 'reviewer2_score', 'reviewer3_score', 'reviewer4_score']].max()
    max_val_str = ""
    for i in range(1, 5):
        if row['reviewer' + str(i) + '_score'] == max_val:
            max_val_str += str(i)

    return max_val_str

# %%
pd.set_option('display.max_rows', 200)

# df['min_time_to_deadline_index'] = df.apply(lambda x: custom_idx_min_time(x), axis=1)
df['min_score_index'] = df.apply(lambda x: custom_idx_min_rec(x), axis=1)
df['max_score_index'] = df.apply(lambda x: custom_idx_max(x), axis=1)

# %% [markdown]
# Things to note:
# - submission time of the reviewer 1 < 2 < 3 < 4, so the latest submitter is always reviewer 4.
#
# Experiment 1: we checked whether the latest submitter is giving the lowest grades (which can cause discrepancy among high variance accepted papers). We have checked who gave the lowest grade here, because among the accepted papers the discrepancy creator is generally the reviewer who gave a really low score (since paper needs to get higher scores from others to get accepted).
#
# We have seen that the distribution is not showing us any bias among the lowest grade givers based on the submission time.

# %%
pd_series = (100 * df[df['decision'].eq("Accept")]['min_score_index'].value_counts(normalize=True)).round(2)
accepted_partition_into_reviewers = pd_series.to_list()
x_names = list(pd_series.index.values)

ax = sns.barplot(x=x_names, y=accepted_partition_into_reviewers)
ax.bar_label(ax.containers[0])
plt.title("Which reviewer submitted the lowest score among all Accepted Papers?")
plt.xlabel('Reviewers that gave minimum score')
plt.ylabel('Percentage (%)')
plt.show()

# %% [markdown]
# Experiment 2: We checked if among accepted high discrepancy papers which reviewer submittion what portion of the lowest scores?
#
# We have observed that there is still not a strong relationship between the submission time and giving the lowest score.

# %%
pd_series = (100 * df[df['decision'].eq("Accept") & df["is_high_variance"].eq(1)]['min_score_index'].value_counts(normalize=True)).round(2)
accepted_partition_into_high_var_reviewers = pd_series.to_list()
x_names = list(pd_series.index.values)

ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers)
ax.bar_label(ax.containers[0])
plt.title("Which reviewer submitted the lowest score among High Discrepancy - Accepted Papers?")
plt.xlabel('Reviewers that gave minimum score')
plt.ylabel('Percentage (%)')
plt.show()

# %% [markdown]
# Experiment 3: We checked if among rejected high discrepancy papers which reviewer submittion what portion of the maximum scores?
#
# 4 olma garantisi gerek veya sonuncu birinci vs. hesabı yapmam lazım

# %%
df.head()
# Out:
#                                                title  \
# 0  Guiding Safe Exploration with Weakest Precondi...
# 1  An Adaptive Entropy-Regularization Framework f...
# 2      AutoSparse: Towards Automated Sparse Training
# 3  Sampling is as easy as learning the score: the...
# 4  RoCourseNet: Distributionally Robust Training ...
#
#                                             keywords  \
# 0  reinforcement learning; safe learning; safe ex...
# 1  Multi-Agent Reinforcement Learning; Entropy Re...
# 2           sparsity; sparse training; deep learning
# 3  diffusion models; score-based generative model...
# 4  Counterfactual Explanation; Algorithmic Recour...
#
#                                                TL;DR  \
# 0  We use an online, weakest-precondition-based a...
# 1  This paper proposes  an adaptive entropy-regul...
# 2                                                NaN
# 3  We prove that given an L2-accurate score estim...
# 4                                                NaN
#
#                                             abstract                cdate  \
# 0  In reinforcement learning for safety-critical ...  2022-09-22 14:36:24
# 1  In this paper, we propose an adaptive entropy-...  2022-09-22 14:33:17
# 2  Sparse training is emerging as a promising ave...  2022-09-22 14:32:39
# 3  We provide theoretical convergence guarantees ...  2022-09-22 14:40:10
# 4  Counterfactual (CF) explanations for machine l...  2022-09-22 14:38:43
#
#                 tmdate  reviewer1_score  \
# 0  2024-11-25 10:13:40                6
# 1  2023-02-14 00:28:54                3
# 2  2023-02-14 00:29:06                5
# 3  2023-02-14 00:27:00                8
# 4  2024-11-25 10:12:40                3
#
#                                 reviewer1_confidence  \
# 0  4: You are confident in your assessment, but n...
# 1  4: You are confident in your assessment, but n...
# 2  4: You are confident in your assessment, but n...
# 3  4: You are confident in your assessment, but n...
# 4  4: You are confident in your assessment, but n...
#
#                       reviewer1_summary_of_the_paper  \
# 0  This paper deals with safe exploration in rein...
# 1  This paper presents an MARL algorithm to adpat...
# 2  This paper first introduces a technique called...
# 3  This paper examines the convergence of SGMs un...
# 4  This submission proposed an approach to solvin...
#
#                    reviewer1_strength_and_weaknesses  \
# 0  ### Strength\n- Interesting and importance pro...
# 1  ### Strengths\n\n1. This paper studies adaptiv...
# 2  Strengths:\n\n- Provided intuitive examples an...
# 3  Strength:\n\n- The presentation is clear.\n\n-...
# 4  Strength:\n\n1. The paper is easy to follow.\n...
#
#   reviewer1_clarity_quality_novelty_and_reproducibility  \
# 0  ### Clarity\nThis paper is mostly well-written...
# 1  The Clarity of this paper can definitely be im...
# 2  Clarity & reproducibility:\n- Some hyperparame...
# 3  The presentation is clear except for a few min...
# 4  The quality of this submission is not high. Th...
#
#                      reviewer1_summary_of_the_review  \
# 0  Though this paper presents a new, promising me...
# 1  This paper studies adaptive entropy regulariza...
# 2  Overall I appreciate the authors' work, and it...
# 3  This paper provides several convergence result...
# 4  I suggest rejecting this paper. For details, p...
#
#                                reviewer1_correctness  \
# 0  2: Several of the paper’s claims are incorrect...
# 1  2: Several of the paper’s claims are incorrect...
# 2  3: Some of the paper’s claims have minor issue...
# 3  3: Some of the paper’s claims have minor issue...
# 4  3: Some of the paper’s claims have minor issue...
#
#         reviewer1_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  2: The contributions are only marginally signi...
# 2  3: The contributions are significant and somew...
# 3  3: The contributions are significant and somew...
# 4  2: The contributions are only marginally signi...
#
#         reviewer1_empirical_novelty_and_significance  \
# 0  2: The contributions are only marginally signi...
# 1  2: The contributions are only marginally signi...
# 2  2: The contributions are only marginally signi...
# 3                                     Not applicable
# 4  2: The contributions are only marginally signi...
#
#   reviewer1_flag_for_ethics_review  reviewer1_length     reviewer1_cdate  \
# 0                              NO.              3055 2022-10-20 09:40:48
# 1                              NO.              4790 2022-10-20 13:11:43
# 2                              NO.              3918 2022-10-24 09:15:54
# 3                              NO.              4594 2022-10-21 20:21:21
# 4                              NO.              3630 2022-10-16 18:53:54
#
#       reviewer1_tmdate  reviewer2_score  \
# 0  2022-11-23 10:36:28                8
# 1  2022-10-20 13:11:43                8
# 2  2022-10-24 09:15:54                6
# 3  2022-11-27 18:11:29                8
# 4  2022-10-16 18:53:54                3
#
#                                 reviewer2_confidence  \
# 0  3: You are fairly confident in your assessment...
# 1  4: You are confident in your assessment, but n...
# 2  5: You are absolutely certain about your asses...
# 3  3: You are fairly confident in your assessment...
# 4  3: You are fairly confident in your assessment...
#
#                       reviewer2_summary_of_the_paper  \
# 0  This paper adapts ideas from formal program an...
# 1  This paper proposes an adaptive entropy-regula...
# 2  The paper introduces Gradient Annealing (GA) a...
# 3  This work provides a convergence guarantee for...
# 4  The authors propose combining adversarial trai...
#
#                    reviewer2_strength_and_weaknesses  \
# 0  # Strengths\n\nThe technique is well motivated...
# 1  - Strengths:\n\t- The proposed framework is we...
# 2  I will go sequentially for both strengths and ...
# 3  Strengths:\n- Well-written and presented clear...
# 4  Strengths: \n- The method is fairly straightfo...
#
#   reviewer2_clarity_quality_novelty_and_reproducibility  \
# 0  The technique and motivation are clearly commu...
# 1  The paper has good clarity overall. Most of th...
# 2  The code snippets are provided in the appendix...
# 3  This paper is exceptionally clear and well-wri...
# 4  - This paper is quite clearly written, and the...
#
#                      reviewer2_summary_of_the_review  \
# 0  The paper contributes a novel algorithm for cr...
# 1  I like the main idea of ADER. It seems to prov...
# 2  While the idea of GA alleviates some of the is...
# 3  While this is a very technical paper, there is...
# 4  This work is of high technical quality and the...
#
#                                reviewer2_correctness  \
# 0  4: All of the claims and statements are well-s...
# 1  4: All of the claims and statements are well-s...
# 2  3: Some of the paper’s claims have minor issue...
# 3  4: All of the claims and statements are well-s...
# 4  4: All of the claims and statements are well-s...
#
#         reviewer2_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  4: The contributions are significant, and do n...
# 2  2: The contributions are only marginally signi...
# 3  4: The contributions are significant, and do n...
# 4  2: The contributions are only marginally signi...
#
#         reviewer2_empirical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  3: The contributions are significant and somew...
# 2  2: The contributions are only marginally signi...
# 3  4: The contributions are significant, and do n...
# 4  2: The contributions are only marginally signi...
#
#   reviewer2_flag_for_ethics_review  reviewer2_length     reviewer2_cdate  \
# 0                              NO.              3272 2022-10-25 00:42:31
# 1                              NO.              4824 2022-10-23 18:43:07
# 2                              NO.              4825 2022-10-27 02:33:37
# 3                              NO.              1575 2022-10-24 02:13:45
# 4                              NO.              2097 2022-10-24 04:04:13
#
#       reviewer2_tmdate  reviewer3_score  \
# 0  2022-10-25 00:42:31              6.0
# 1  2022-10-23 18:43:07              6.0
# 2  2022-12-05 02:01:28              3.0
# 3  2022-10-24 02:13:45              8.0
# 4  2022-10-24 04:04:13              3.0
#
#                                 reviewer3_confidence  \
# 0  3: You are fairly confident in your assessment...
# 1  3: You are fairly confident in your assessment...
# 2  5: You are absolutely certain about your asses...
# 3  3: You are fairly confident in your assessment...
# 4  4: You are confident in your assessment, but n...
#
#                       reviewer3_summary_of_the_paper  \
# 0  The paper proposes a method for safe reinforce...
# 1  This paper aims to solve the exploration-explo...
# 2  This paper proposes gradient annealing method ...
# 3  This paper provides convergence bounds for sco...
# 4  The paper tackles the problem of generating co...
#
#                    reviewer3_strength_and_weaknesses  \
# 0  + The approach reduces the number of safety vi...
# 1  - The strength of the paper comes from the ide...
# 2  Strengths\n\n1. This paper investigates differ...
# 3  Strength: The results are pretty impressive gi...
# 4  ## Strenghts:\n\nThe authors are effective in ...
#
#   reviewer3_clarity_quality_novelty_and_reproducibility  \
# 0  The paper is overall well written and presente...
# 1  This paper is well-written with high clarity. ...
# 2  To sum up, the clarity and quality of this pap...
# 3                 Clearly written and novel results.
# 4  The paper explanation of the method is clear w...
#
#                      reviewer3_summary_of_the_review  \
# 0  The paper builds on previous work on safe rein...
# 1  I would give marginally above the acceptance t...
# 2   I think this paper needs major revision, both...
# 3  The paper reads well and presents important re...
# 4  While the paper has some strengths, as highlig...
#
#                                reviewer3_correctness  \
# 0  4: All of the claims and statements are well-s...
# 1  4: All of the claims and statements are well-s...
# 2  3: Some of the paper’s claims have minor issue...
# 3  4: All of the claims and statements are well-s...
# 4  3: Some of the paper’s claims have minor issue...
#
#         reviewer3_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1  3: The contributions are significant and somew...
# 2  1: The contributions are neither significant n...
# 3  4: The contributions are significant, and do n...
# 4  2: The contributions are only marginally signi...
#
#         reviewer3_empirical_novelty_and_significance  \
# 0  2: The contributions are only marginally signi...
# 1  2: The contributions are only marginally signi...
# 2  1: The contributions are neither significant n...
# 3  4: The contributions are significant, and do n...
# 4                                     Not applicable
#
#   reviewer3_flag_for_ethics_review  reviewer3_length     reviewer3_cdate  \
# 0                              NO.            1508.0 2022-10-26 00:04:46
# 1                              NO.            2716.0 2022-10-24 22:26:06
# 2                              NO.            2958.0 2022-10-27 05:32:06
# 3                              NO.            2385.0 2022-10-25 14:35:52
# 4                              NO.            3586.0 2022-10-24 23:15:45
#
#       reviewer3_tmdate  reviewer4_score  \
# 0  2022-10-26 00:04:46              6.0
# 1  2022-10-24 22:26:06              NaN
# 2  2022-10-27 05:32:06              3.0
# 3  2022-10-25 14:45:19              8.0
# 4  2022-10-24 23:15:45              6.0
#
#                                 reviewer4_confidence  \
# 0  4: You are confident in your assessment, but n...
# 1                                                NaN
# 2  5: You are absolutely certain about your asses...
# 3  3: You are fairly confident in your assessment...
# 4  4: You are confident in your assessment, but n...
#
#                       reviewer4_summary_of_the_paper  \
# 0  The paper proposes a safe RL algorithm, Symbol...
# 1                                                NaN
# 2  In this paper, the authors propose a new spars...
# 3  The paper proposes a theoretical analysis of S...
# 4  The paper proposes an architecture and a train...
#
#                    reviewer4_strength_and_weaknesses  \
# 0  Strengths:\n* SPICE’s use of formal methods pr...
# 1                                                NaN
# 2  Strength:\n1.\tThis paper is well written and ...
# 3  Despite the strong claims, the paper seems to ...
# 4  + The paper deals with a practical problem; ge...
#
#   reviewer4_clarity_quality_novelty_and_reproducibility  \
# 0  The paper is generally clear. I appreciate the...
# 1                                                NaN
# 2                  See the strength and weaknesses.
# 3  The paper is very clear, despite the complex s...
# 4  The paper is written clearly and is easy to fo...
#
#                      reviewer4_summary_of_the_review  \
# 0  I like the proposed approach and its associate...
# 1                                                NaN
# 2  1. The proposed method seems tricky and not el...
# 3  Overall I think the paper introduces very stro...
# 4  The paper solves an important problem. The exp...
#
#                                reviewer4_correctness  \
# 0  4: All of the claims and statements are well-s...
# 1                                                NaN
# 2  2: Several of the paper’s claims are incorrect...
# 3  3: Some of the paper’s claims have minor issue...
# 4  4: All of the claims and statements are well-s...
#
#         reviewer4_technical_novelty_and_significance  \
# 0  3: The contributions are significant and somew...
# 1                                                NaN
# 2  2: The contributions are only marginally signi...
# 3  3: The contributions are significant and somew...
# 4  2: The contributions are only marginally signi...
#
#         reviewer4_empirical_novelty_and_significance  \
# 0  2: The contributions are only marginally signi...
# 1                                                NaN
# 2  1: The contributions are neither significant n...
# 3                                     Not applicable
# 4  2: The contributions are only marginally signi...
#
#   reviewer4_flag_for_ethics_review  reviewer4_length     reviewer4_cdate  \
# 0                              NO.            3082.0 2022-11-03 08:08:39
# 1                              NaN               NaN                 NaT
# 2                              NO.            2254.0 2022-10-27 20:14:54
# 3                              NO.            5316.0 2022-10-27 22:09:32
# 4                              NO.            2937.0 2022-10-29 20:23:57
#
#       reviewer4_tmdate decision  paper_id reviewer1_time_to_deadline  \
# 0  2022-12-14 03:46:36   Accept         0            4 days 14:19:12
# 1                  NaN   Reject         1            4 days 10:48:17
# 2  2022-10-27 20:14:54   Reject         2            0 days 14:44:06
# 3  2022-10-27 22:09:32   Accept         3            3 days 03:38:39
# 4  2022-10-29 20:23:57   Reject         4            8 days 05:06:06
#
#   reviewer2_time_to_deadline reviewer3_time_to_deadline  \
# 0          -1 days +23:17:29          -2 days +23:55:14
# 1            1 days 05:16:53            0 days 01:33:54
# 2          -3 days +21:26:23          -3 days +18:27:54
# 3            0 days 21:46:15          -1 days +09:24:08
# 4            0 days 19:55:47            0 days 00:44:15
#
#   reviewer4_time_to_deadline  max_score  min_score  max_min_score_diff  \
# 0         -10 days +15:51:21        8.0        6.0                 2.0
# 1                        NaT        8.0        3.0                 5.0
# 2          -3 days +03:45:06        6.0        3.0                 3.0
# 3          -3 days +01:50:28        8.0        8.0                 0.0
# 4          -5 days +03:36:03        6.0        3.0                 3.0
#
#    is_high_variance min_score_index max_score_index
# 0             False             134               2
# 1              True               1               2
# 2             False              34               2
# 3             False            1234            1234
# 4             False             123               4

# %%
df[["reviewer1_score", "reviewer2_score", "reviewer3_score", "reviewer4_score"]]
df["num_valid_reviews"] = df[["reviewer1_score", "reviewer2_score", "reviewer3_score", "reviewer4_score"]].apply(lambda x: 4 - x.isnull().sum(), axis=1)
df["last_reviewer_score"] = df.apply(lambda x: x[f"reviewer{x['num_valid_reviews']}_score"], axis=1)

df["is_first_higher"] = df.apply(lambda x: x["reviewer1_score"] > x["last_reviewer_score"], axis=1)
print(df["is_first_higher"].value_counts())
print(df["num_valid_reviews"].value_counts())
# Out:
# is_first_higher
# False    2633
# True     1163
# Name: count, dtype: int64
# num_valid_reviews
# 4    2628
# 3    1166
# 2       2
# Name: count, dtype: int64

# %%
pd_series = (100 * df[df['decision'].eq("Reject") & df["is_high_variance"].eq(1)]['is_first_higher'].value_counts(normalize=True))
pd_series
# Out:
# is_first_higher
# False    61.165049
# True     38.834951
# Name: proportion, dtype: float64

# %%
pd_series = (100 * df[df['decision'].eq("Reject") & df["is_high_variance"].eq(1)]['max_score_index'].value_counts(normalize=True)).round(2)
accepted_partition_into_high_var_reviewers = pd_series.to_list()
x_names = list(pd_series.index.values)

ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers)
ax.bar_label(ax.containers[0])
plt.title("Which reviewer submitted the highest score among High Discrepancy - Rejected Papers?")
plt.xlabel('Reviewers that gave maximum score')
plt.ylabel('Percentage (%)')
plt.show()

# %%
pd_series = (100 * df[df['decision'].eq("Reject") & df["is_high_variance"].eq(1)]['max_score_index'].value_counts(normalize=True)).round(2)
accepted_partition_into_high_var_reviewers = pd_series.to_list()
x_names = list(pd_series.index.values)

ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers)
ax.bar_label(ax.containers[0])
plt.title("Which reviewer submitted the highest score among High Discrepancy - Rejected Papers?")
plt.xlabel('Reviewers that gave maximum score')
plt.ylabel('Percentage (%)')
plt.show()

# %%
def modify_max_score_index(row):
    max_index = row["max_score_index"]
    # Check if all indices greater than max_index are NaN
    if max_index == "2" and pd.isna(row["reviewer3_score"]) and pd.isna(row["reviewer4_score"]):  # If both index 3 and 4 are NaN
        return "last"
    elif max_index == "3" and pd.isna(row["reviewer4_score"]):  # If only index 4 is NaN
        return "last"
    elif max_index == "4":  # If max_score_index itself is 4
        return "last"
    return "not_last"

df["modified_max_score_index"] = df.apply(modify_max_score_index, axis=1)
print(df["modified_max_score_index"].value_counts())

pd_series_last = (
    df[df['decision'].eq("Reject") & df["is_high_variance"].eq(1) & df["modified_max_score_index"].eq("last")]
    ["modified_max_score_index"]
    .value_counts()
)

# Step 3: Get the count of remaining values from max_score_index
pd_series_rest = (
    df[df['decision'].eq("Reject") & df["is_high_variance"].eq(1) & df["modified_max_score_index"].ne("last")]
    ["max_score_index"]
    .value_counts()
)

total_count = df[df['decision'].eq("Reject") & df["is_high_variance"].eq(1)].shape[0]

# Step 4: Combine both series and normalize them to sum to 100%
pd_series = pd.concat([pd_series_last, pd_series_rest]).sort_index()
pd_series = (pd_series / total_count * 100).round(2)  # Normalize to percentage

# Prepare data for plotting
pd_series = pd_series.sort_values(ascending=False)
accepted_partition_into_high_var_reviewers = pd_series.to_list()
x_names = list(pd_series.index.values)

# Create bar plot
pal = sns.color_palette(palette="Purples_r", n_colors=len(pd_series))

ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, palette=np.array(pal)[::-1], hue=accepted_partition_into_high_var_reviewers)
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f')
plt.title("Which reviewer submitted the highest score among High Discrepancy - Rejected Papers?")
plt.xlabel('Reviewers that gave maximum score')
plt.ylabel('Percentage (%)')
plt.legend([],[], frameon=False)

vector_image_path = "/mnt/data/high_discrepancy_reviewers.svg"
# plt.savefig(vector_image_path, format="svg", bbox_inches="tight")

# Show plot
plt.savefig("seaborn_plot.svg", format='svg')
#plt.show()
# Out:
# modified_max_score_index
# not_last    3272
# last         524
# Name: count, dtype: int64
# /var/folders/fl/8ng_m3ld6734_9svpd_k619m0000gn/T/ipykernel_67114/3984093068.py:42: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, palette=np.array(pal)[::-1], hue=accepted_partition_into_high_var_reviewers)
# /var/folders/fl/8ng_m3ld6734_9svpd_k619m0000gn/T/ipykernel_67114/3984093068.py:42: UserWarning: The palette list has more values (13) than needed (11), which may not be intended.
#   ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, palette=np.array(pal)[::-1], hue=accepted_partition_into_high_var_reviewers)

# %%
def modify_min_score_index(row):
    max_index = row["min_score_index"]
    # Check if all indices greater than max_index are NaN
    if max_index == "2" and pd.isna(row["reviewer3_score"]) and pd.isna(row["reviewer4_score"]):  # If both index 3 and 4 are NaN
        return "last"
    elif max_index == "3" and pd.isna(row["reviewer4_score"]):  # If only index 4 is NaN
        return "last"
    elif max_index == "4":  # If max_score_index itself is 4
        return "last"
    return "not_last"

df["modified_min_score_index"] = df.apply(modify_min_score_index, axis=1)
print(df["modified_min_score_index"].value_counts())

pd_series_last = (
    df[df['decision'].eq("Accept") & df["is_high_variance"].eq(1) & df["modified_min_score_index"].eq("last")]
    ["modified_min_score_index"]
    .value_counts()
)

# Step 3: Get the count of remaining values from max_score_index
pd_series_rest = (
    df[df['decision'].eq("Accept") & df["is_high_variance"].eq(1) & df["modified_min_score_index"].ne("last")]
    ["min_score_index"]
    .value_counts()
)

total_count = df[df['decision'].eq("Accept") & df["is_high_variance"].eq(1)].shape[0]

# Step 4: Combine both series and normalize them to sum to 100%
pd_series = pd.concat([pd_series_last, pd_series_rest]).sort_index()
pd_series = (pd_series / total_count * 100).round(2)  # Normalize to percentage

# Prepare data for plotting
pd_series = pd_series.sort_values(ascending=False)
accepted_partition_into_high_var_reviewers = pd_series.to_list()
x_names = list(pd_series.index.values)

# Create bar plot
pal = sns.color_palette(palette="Purples_r", n_colors=len(pd_series))

ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, palette=np.array(pal)[::-1], hue=accepted_partition_into_high_var_reviewers)
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f')
plt.title("Which reviewer submitted the lowest score among High Discrepancy - Accepted Papers?")
plt.xlabel('Reviewers that gave minimum score')
plt.ylabel('Percentage (%)')
plt.legend([],[], frameon=False)

# vector_image_path = "/mnt/data/high_discrepancy_reviewers.svg"
# # plt.savefig(vector_image_path, format="svg", bbox_inches="tight")

# # Show plot
# plt.savefig("seaborn_plot.svg", format='svg')
#plt.show()
# Out:
# modified_min_score_index
# not_last    3310
# last         486
# Name: count, dtype: int64
# /var/folders/fl/8ng_m3ld6734_9svpd_k619m0000gn/T/ipykernel_67114/3639247947.py:42: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, palette=np.array(pal)[::-1], hue=accepted_partition_into_high_var_reviewers)
# /var/folders/fl/8ng_m3ld6734_9svpd_k619m0000gn/T/ipykernel_67114/3639247947.py:42: UserWarning: The palette list has more values (12) than needed (8), which may not be intended.
#   ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, palette=np.array(pal)[::-1], hue=accepted_partition_into_high_var_reviewers)

# %% [markdown]
# Experiment 4: What portion of the late submissions belong to high variance papers?
#
# We have observed that the portion of high variance papers among the reviews submittion (0.5, 1, 3 and 10 days) before the deadline does not change. Thus, there is no relationship between being a late submitter and creating discrepancy by giving a score that is far from the consensus.

# %%
review_df_clean["time_to_deadline"].le(pd.Timedelta(days=-1)).value_counts()
# Out:
# time_to_deadline
# False    10006
# True      4008
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 6, figsize=(12, 5), sharey=True)
days_list = [-10, -1, 0.5, 1, 3, 10]

for i, days in enumerate(days_list):
    pd_series = (100 * review_df_clean[review_df_clean['decision'].eq("Accept") & 
                                review_df_clean["time_to_deadline"].le(pd.Timedelta(days=days))]['is_high_variance']
                 .value_counts(normalize=True)).round(2)
    
    accepted_partition_into_high_var_reviewers = pd_series.to_list()
    x_names = ["Low Discrepancy", "High Discrepancy"]

    ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, ax=axes[i])
    ax.bar_label(ax.containers[0])
    ax.set_title(f"Days <= {days}")
    ax.set_ylabel('Percentage (%)' if i == 0 else "")

plt.suptitle("What portion of the late submitted reviews belong to high variance papers?")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 6, figsize=(12, 5), sharey=True)
days_list = [-10, -1, 0.5, 1, 3, 10]

for i, days in enumerate(days_list):
    # join review_df_clean with df from paper_id to get if last_reviewer_score is max or min
    pd_series = (100 * review_df_clean[review_df_clean['decision'].eq("Accept") & 
                                review_df_clean["time_to_deadline"].between(pd.Timedelta(days=-40), pd.Timedelta(days=-12))]['is_high_variance']
                 .value_counts(normalize=True)).round(2)
    
    accepted_partition_into_high_var_reviewers = pd_series.to_list()
    x_names = ["Low Discrepancy", "High Discrepancy"]

    ax = sns.barplot(x=x_names, y=accepted_partition_into_high_var_reviewers, ax=axes[i])
    ax.bar_label(ax.containers[0])
    ax.set_title(f"Days <= {days}")
    ax.set_ylabel('Percentage (%)' if i == 0 else "")

plt.suptitle("What portion of the late submitted reviews belong to high variance papers?")
plt.tight_layout()
plt.show()

# %%
filtered_papers = review_df_clean[
    review_df_clean["time_to_deadline"].between(pd.Timedelta(days=-10), pd.Timedelta(days=0))
]

print(len(filtered_papers))
# Out:
# 6883

# %%
(100 * df[df['decision'].eq("Accept")]['max_score_index'].value_counts(normalize=True)).round(2)
# Out:
# max_score_index
# 1       13.03
# 3       12.27
# 2       11.38
# 123      9.66
# 4        7.50
# 12       7.37
# 13       6.68
# 23       6.23
# 1234     6.17
# 14       3.94
# 124      3.56
# 24       3.18
# 34       3.18
# 234      3.12
# 134      2.73
# Name: proportion, dtype: float64

# %%
review_df_clean["reviewer_cdate"].dt

# %%
import matplotlib.pyplot as plt
import numpy as np

late_submissions = "2022-11-10 00:00:00" # buffer time until this date
on_time_submissions = "2022-10-23 00:00:00" # until 2 day before the deadline
close_to_deadline_submissions = ("2022-10-23 00:00:00", "2022-10-25 00:00:00") # 2 days before the deadline

# Simulated data: cumulative reviews over time
days = review_df_clean["reviewer_cdate"]
reviews = np.cumsum(np.random.randint(50, 300, size=len(days)))  # Cumulative sum of reviews

review_df_clean["reviewer_date"] = review_df_clean["reviewer_cdate"].dt.date
# Step 2: Group by the datetime column and calculate daily totals
daily_reviews = review_df_clean.groupby("reviewer_date").size().reset_index(name="daily_total")
# Step 3: Perform cumulative sum over the grouped data
daily_reviews["cumulative_reviews"] = daily_reviews["daily_total"].cumsum()


days = daily_reviews["reviewer_date"]
reviews = daily_reviews["cumulative_reviews"]

# Key milestone dates (days in July & August)
milestones = {
    "reviews start": "2022-10-12 00:00:00",  # Review submission deadline
    "reviews deadline": "2022-10-25 00:00:00",
    "reviews released": "2022-11-05 01:00:00",
    "rebuttal start": "2022-11-10 00:00:00",
    "rebuttal ends": "2022-11-23 00:00:00",
    "decisions despatched": "2023-01-21 02:00:00"
}

milestones = {key: pd.to_datetime(value).date() for key, value in milestones.items()}

milestone_days = [d for d in milestones.values()]

sns.set_theme(style="whitegrid")

# Figure size
plt.figure(figsize=(10, 6))

# Plot the cumulative reviews line
sns.lineplot(x=days, y=reviews, label="Cumulative Reviews", linewidth=2.5, color="darkblue")

# Add vertical milestone lines
for label, day in zip(milestones.keys(), milestone_days):
    plt.axvline(x=day, linestyle="--", color="red", alpha=0.7)
    middle_y = (max(reviews) + min(reviews)) / 6
    plt.text(day, middle_y, label, rotation=90, verticalalignment='center', 
             horizontalalignment='center', fontsize=10, color="darkred", bbox=dict(facecolor='white', alpha=0.9, edgecolor='none'))

# Add labels, title, and legend
plt.xlabel("Date", fontsize=12, labelpad=10)
plt.ylabel("Number of Reviews", fontsize=12, labelpad=10)
plt.title("Cumulative Count of Received Reviews", fontsize=14, pad=15)
plt.legend(loc="upper left", fontsize=10)
plt.xticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()

# %%
daily_reviews.columns
# Out:
# Index(['reviewer_date', 'daily_total', 'cumulative_reviews'], dtype='object')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'review_df_clean' contains a 'reviewer_score' column
# Calculate cumulative average of reviewer_score
review_df_clean["reviewer_date"] = review_df_clean["reviewer_cdate"].dt.date
review_df_clean = review_df_clean.sort_values("reviewer_cdate")  # Ensure data is sorted by date

# Step 2: Group by date and calculate daily totals for reviews
daily_reviews = review_df_clean.groupby("reviewer_date").size().reset_index(name="daily_total")

daily_reviews["cumulative_reviews"] = daily_reviews["daily_total"].cumsum()

# Calculate cumulative average score grouped by date
daily_reviews["cumulative_avg_score"] = review_df_clean["review_score"].expanding().mean()


days = daily_reviews["reviewer_date"]

# Key milestone dates
milestones = {
    "reviews start": "2022-10-12 01:00:00",
    "reviews deadline": "2022-10-24 23:59:59",
    "reviews released": "2022-11-05 01:00:00",
    "rebuttal start": "2022-11-10 00:00:00",
    "rebuttal ends": "2022-11-22 23:59:59",
    "decisions despatched": "2023-01-21 02:00:00"
}

milestones = {key: pd.to_datetime(value).date() for key, value in milestones.items()}
milestone_days = [d for d in milestones.values()]

# Seaborn theme
sns.set_theme(style="whitegrid")

# Create the plot
fig, ax1 = plt.subplots(figsize=(12, 7))

# Plot the cumulative reviews on the left y-axis
ax1.set_title("Cumulative Count of Reviews and Average Reviewer Score", fontsize=14, pad=15)
sns.lineplot(x=days, y=daily_reviews["cumulative_reviews"],
             label="Cumulative Reviews", linewidth=2.5, color="darkblue", ax=ax1)

# Customize the left y-axis
ax1.set_xlabel("Date", fontsize=12, labelpad=10)
ax1.set_ylabel("Number of Cumulative Reviews", fontsize=12, labelpad=10, color="darkblue")
ax1.tick_params(axis="y", labelcolor="darkblue")
ax1.legend(loc="upper left", fontsize=10)
ax1.grid(visible=True, linestyle="--", alpha=0.6)

# Add vertical milestone lines
for label, day in zip(milestones.keys(), milestone_days):
    ax1.axvline(x=day, linestyle="--", color="red", alpha=0.7)
    middle_y = (max(daily_reviews["cumulative_reviews"]) + min(daily_reviews["cumulative_reviews"])) / 6
    ax1.text(day, middle_y, label, rotation=90, verticalalignment='center',
             horizontalalignment='center', fontsize=10, color="darkred",
             bbox=dict(facecolor='white', alpha=0.9, edgecolor='none'))

# Create a secondary y-axis for the cumulative average score
ax2 = ax1.twinx()
sns.lineplot(x=days, y=daily_reviews["cumulative_avg_score"],
            label="Cumulative Avg Score", linewidth=2.5, color="green", ax=ax2)
# # Customize the right y-axis
ax2.set_ylabel("Cumulative Avg Score", fontsize=12, labelpad=10, color="green")
ax2.tick_params(axis="y", labelcolor="green")
ax2.legend(loc="upper right", fontsize=10)

# xticks
ax1.set_xticks(milestone_days)
ax1.set_xticklabels([milestones[label].strftime('%b')+" "+str(milestones[label].day) for label in milestones.keys()], rotation=45, fontsize=10)

ax2.set_ylim(0, 8)  # Add some padding to the min/max values

# Adjust layout
fig.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, sys
from pathlib import Path

pwd  = Path(os.getcwd())
sys.path.append(str(pwd.parent)) # needed to use "koray" module
from koray.feature_calculation.util import get_features

conference_invitations = ['ICLR.cc/2023/Conference/-/Blind_Submission']
feature_df = list(get_features(conference_invitations, disable_cache=True))
df = pd.concat(feature_df)
# Out:
# Calculating features for ICLR.cc/2023/Conference/-/Blind_Submission (1/1)
# ✔ Successfully loaded dataframes
# 100%|██████████| 3796/3796 [00:15<00:00, 242.73it/s]
# /Users/busraasan/codes/data-literacy-group16/koray/feature_calculation/paper_features.py:131: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# /Users/busraasan/codes/data-literacy-group16/koray/feature_calculation/paper_features.py:131: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# /Users/busraasan/codes/data-literacy-group16/koray/feature_calculation/paper_features.py:131: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# /Users/busraasan/codes/data-literacy-group16/koray/feature_calculation/paper_features.py:131: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# /Users/busraasan/codes/data-literacy-group16/koray/feature_calculation/paper_features.py:131: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# ✔ Successfully calculated features

# %%
# Simulated data: cumulative reviews over time
days = df["reviewer_cdate"]
reviews = np.cumsum(np.random.randint(50, 300, size=len(days)))  # Cumulative sum of reviews

review_df_clean["reviewer_date"] = review_df_clean["reviewer_cdate"].dt.date
# Step 2: Group by the datetime column and calculate daily totals
daily_reviews = review_df_clean.groupby("reviewer_date").size().reset_index(name="daily_total")
# Step 3: Perform cumulative sum over the grouped data
daily_reviews["cumulative_reviews"] = daily_reviews["daily_total"].cumsum()

days = daily_reviews["reviewer_date"]
reviews = daily_reviews["cumulative_reviews"]

# Key milestone dates (days in July & August)
milestones = {
    "reviews start": "2022-10-12 00:00:00",  # Review submission deadline
    "reviews deadline": "2022-10-24 00:00:00",
    "reviews released": "2022-11-05 01:00:00",
    "rebuttal start": "2022-11-10 00:00:00",
    "rebuttal ends": "2022-11-23 00:00:00",
    # "decisions despatched": "2023-01-21 02:00:00"
}

milestones = {key: pd.to_datetime(value).date() for key, value in milestones.items()}

milestone_days = [d for d in milestones.values()]

# Plot the cumulative reviews
plt.figure(figsize=(8, 5))
plt.plot(days, reviews, label="Cumulative Reviews")

# Add vertical milestone lines
for label, day in zip(milestones.keys(), milestone_days):
    print(type(daily_reviews["reviewer_date"].iloc[0]))
    print(label, type(day))
    plt.axvline(x=day, linestyle='-', color='blue')
    plt.text(day, max(reviews) * 0.9, label, rotation=90, verticalalignment='bottom', fontsize=10)

# Formatting
plt.xlabel("Date")
plt.ylabel("Number of Reviews")
plt.title("Cumulative Count of Received Reviews")
plt.grid(True, linestyle="--", alpha=0.6)

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/brain-align/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reviewer_cdate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[143], line 2
#       1 # Simulated data: cumulative reviews over time
# ----> 2 days = df["reviewer_cdate"]
#       3 reviews = np.cumsum(np.random.randint(50, 300, size=len(days)))  # Cumulative sum of reviews
#       5 review_df_clean["reviewer_date"] = review_df_clean["reviewer_cdate"].dt.date
#
# File ~/anaconda3/envs/brain-align/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/brain-align/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'reviewer_cdate'

# %%
review_df_clean["reviewer_date"] = review_df_clean["reviewer_cdate"].dt.date
# Step 2: Group by the datetime column and calculate daily totals
daily_reviews = review_df_clean.groupby("reviewer_date").size().reset_index(name="daily_total")

# Step 3: Perform cumulative sum over the grouped data
daily_reviews["cumulative_reviews"] = daily_reviews["daily_total"].cumsum()
# Out:
#    reviewer_date  daily_total  cumulative_reviews
# 0     2022-10-12           11                  11
# 1     2022-10-13           65                  76
# 2     2022-10-14           74                 150
# 3     2022-10-15           62                 212
# 4     2022-10-16           85                 297
# 5     2022-10-17          178                 475
# 6     2022-10-18          145                 620
# 7     2022-10-19          236                 856
# 8     2022-10-20          353                1209
# 9     2022-10-21          525                1734
# 10    2022-10-22          563                2297
# 11    2022-10-23         1286                3583
# 12    2022-10-24         3190                6773
# 13    2022-10-25         3233               10006
# 14    2022-10-26          936               10942
# 15    2022-10-27          653               11595
# 16    2022-10-28          423               12018
# 17    2022-10-29          260               12278
# 18    2022-10-30          294               12572
# 19    2022-10-31          334               12906
# 20    2022-11-01          238               13144
# 21    2022-11-02          231               13375
# 22    2022-11-03          281               13656
# 23    2022-11-04          218               13874
# 24    2022-11-05            5               13879
