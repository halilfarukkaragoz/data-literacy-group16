# %% [markdown]
# # feature calc with agg functions

# %%
import pandas as pd 
import os
from pathlib import Path

import numpy as np
from tqdm import tqdm
tqdm.pandas()

# %%
pwd  = Path(os.getcwd())
pwd
# Out:
# PosixPath('/Users/koray/data-literacy-group13/data')

# %%
import pickle

picklefile = pwd.parent / "scraping" / 'scraped-dataframes.pkl'

# loading from pickle file
with open(picklefile, 'rb') as f:
    data = pickle.load(f)
    paper_df = pd.DataFrame(data['paper_df'])
    review_df = pd.DataFrame(data['review_df'])
    other_replies_df = pd.DataFrame(data['other_replies_df'])

# %%
paper_df
# Out:
#                id     original          cdate         pdate         odate  \
# 0     zzDrPqn57DL  HXF7e04ViJI  1652737363731  1.667239e+12           NaN
# 1     zz0FC7qBpkh   7cZ94HqqMn  1652737830798  1.667239e+12           NaN
# 2      zyrBT58h_J  GMUaJ0joiTU  1652737730463  1.667239e+12           NaN
# 3     zvNMzjOizmn  r9JcSZTViEx  1652737743370  1.667239e+12           NaN
# 4     zuL5OYIBgcV  AH5xEKmMUnH  1652737344613  1.667239e+12           NaN
# ...           ...          ...            ...           ...           ...
# 6615  -4Maz7s3YXz   SUZNkFXFIh  1663850125224  1.675280e+12  1.664468e+12
# 6616  -4DiyBMgv9m  SRt6LbSJc-u  1663850541741  1.675280e+12  1.664468e+12
# 6617   -2zfgNS917   KQ3zOvPeO3  1663849815845  1.675279e+12  1.664468e+12
# 6618  -1x2-lp1eZf  e-VvI0lh-OS  1663850128070  1.675280e+12  1.664468e+12
# 6619   -0tPmzgXS5  s3mA4mRGFzT  1663849824402  1.675280e+12  1.664468e+12
#
#      mdate         tcdate         tmdate ddate  number  \
# 0     None  1652737363731  1720019111771  None    2310
# 1     None  1652737830798  1720018324012  None   12079
# 2     None  1652737730463  1720018470521  None    9989
# 3     None  1652737743370  1720018453615  None   10262
# 4     None  1652737344613  1720019149089  None    1891
# ...    ...            ...            ...   ...     ...
# 6615  None  1663850125224  1676330899214  None    2785
# 6616  None  1663850541741  1676330786166  None    6214
# 6617  None  1663849815845  1732526208563  None     143
# 6618  None  1663850128070  1676330898359  None    2809
# 6619  None  1663849824402  1676330986530  None     211
#
#                                                 content        forum referent  \
# 0     {'title': 'BEVFusion: A Simple and Robust LiDA...  zzDrPqn57DL     None
# 1     {'title': 'The Missing Invariance Principle fo...  zz0FC7qBpkh     None
# 2     {'title': 'Sustainable Online Reinforcement Le...   zyrBT58h_J     None
# 3     {'title': 'Langevin Autoencoders for Learning ...  zvNMzjOizmn     None
# 4     {'title': 'Non-deep Networks', 'authorids': ['...  zuL5OYIBgcV     None
# ...                                                 ...          ...      ...
# 6615  {'title': 'Towards Understanding Robust Memori...  -4Maz7s3YXz     None
# 6616  {'title': 'Identifying Phase Transition Thresh...  -4DiyBMgv9m     None
# 6617  {'title': 'BEVDistill: Cross-Modal BEV Distill...   -2zfgNS917     None
# 6618  {'title': 'Rethinking Deep Spiking Neural Netw...  -1x2-lp1eZf     None
# 6619  {'title': 'Probing into Overfitting for Video ...   -0tPmzgXS5     None
#
#                                          invitation replyto     readers  \
# 0     NeurIPS.cc/2022/Conference/-/Blind_Submission    None  [everyone]
# 1     NeurIPS.cc/2022/Conference/-/Blind_Submission    None  [everyone]
# 2     NeurIPS.cc/2022/Conference/-/Blind_Submission    None  [everyone]
# 3     NeurIPS.cc/2022/Conference/-/Blind_Submission    None  [everyone]
# 4     NeurIPS.cc/2022/Conference/-/Blind_Submission    None  [everyone]
# ...                                             ...     ...         ...
# 6615     ICLR.cc/2023/Conference/-/Blind_Submission    None  [everyone]
# 6616     ICLR.cc/2023/Conference/-/Blind_Submission    None  [everyone]
# 6617     ICLR.cc/2023/Conference/-/Blind_Submission    None  [everyone]
# 6618     ICLR.cc/2023/Conference/-/Blind_Submission    None  [everyone]
# 6619     ICLR.cc/2023/Conference/-/Blind_Submission    None  [everyone]
#
#      nonreaders                    signatures                       writers
# 0            []  [NeurIPS.cc/2022/Conference]  [NeurIPS.cc/2022/Conference]
# 1            []  [NeurIPS.cc/2022/Conference]  [NeurIPS.cc/2022/Conference]
# 2            []  [NeurIPS.cc/2022/Conference]  [NeurIPS.cc/2022/Conference]
# 3            []  [NeurIPS.cc/2022/Conference]  [NeurIPS.cc/2022/Conference]
# 4            []  [NeurIPS.cc/2022/Conference]  [NeurIPS.cc/2022/Conference]
# ...         ...                           ...                           ...
# 6615         []     [ICLR.cc/2023/Conference]     [ICLR.cc/2023/Conference]
# 6616         []     [ICLR.cc/2023/Conference]     [ICLR.cc/2023/Conference]
# 6617         []     [ICLR.cc/2023/Conference]     [ICLR.cc/2023/Conference]
# 6618         []     [ICLR.cc/2023/Conference]     [ICLR.cc/2023/Conference]
# 6619         []     [ICLR.cc/2023/Conference]     [ICLR.cc/2023/Conference]
#
# [6620 rows x 19 columns]

# %%
review_df
# Out:
#                 id original  number          cdate  mdate ddate  \
# 0       VrENUT1h6-     None       1  1656944073004    NaN  None
# 1      B8g021IaaAm     None       2  1657487808768    NaN  None
# 2      HNAOCsCSzZw     None       3  1657585011273    NaN  None
# 3       uVn6Us0aP_     None       4  1657587291965    NaN  None
# 4      Hd6Ce57Ircd     None       5  1658042263683    NaN  None
# ...            ...      ...     ...            ...    ...   ...
# 39365  nC5K4ES2guS     None       4  1667286565916    NaN  None
# 39366   CA9y6TTZGq     None       5  1667293855370    NaN  None
# 39369  UgGANSuJ2pm     None       1  1665995913803    NaN  None
# 39370  eveHfO7L3IV     None       2  1666649632568    NaN  None
# 39371  u4_v7_F4NWE     None       3  1667242787303    NaN  None
#
#               tcdate         tmdate tddate        forum      replyto  \
# 0      1656944073004  1656944073004   None  zzDrPqn57DL  zzDrPqn57DL
# 1      1657487808768  1660833391821   None  zzDrPqn57DL  zzDrPqn57DL
# 2      1657585011273  1657585011273   None  zzDrPqn57DL  zzDrPqn57DL
# 3      1657587291965  1657587291965   None  zzDrPqn57DL  zzDrPqn57DL
# 4      1658042263683  1658049110257   None  zzDrPqn57DL  zzDrPqn57DL
# ...              ...            ...    ...          ...          ...
# 39365  1667286565916  1667286565916   None  -1x2-lp1eZf  -1x2-lp1eZf
# 39366  1667293855370  1667294200802   None  -1x2-lp1eZf  -1x2-lp1eZf
# 39369  1665995913803  1666019168781   None   -0tPmzgXS5   -0tPmzgXS5
# 39370  1666649632568  1669110135900   None   -0tPmzgXS5   -0tPmzgXS5
# 39371  1667242787303  1668672033429   None   -0tPmzgXS5   -0tPmzgXS5
#
#                                               invitation  \
# 0      NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 1      NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 2      NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 3      NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 4      NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# ...                                                  ...
# 39365  ICLR.cc/2023/Conference/Paper2809/-/Official_R...
# 39366  ICLR.cc/2023/Conference/Paper2809/-/Official_R...
# 39369  ICLR.cc/2023/Conference/Paper211/-/Official_Re...
# 39370  ICLR.cc/2023/Conference/Paper211/-/Official_Re...
# 39371  ICLR.cc/2023/Conference/Paper211/-/Official_Re...
#
#                                                  content  \
# 0      {'rating': '7: Accept: Technically solid paper...
# 1      {'rating': '5: Borderline accept: Technically ...
# 2      {'rating': '5: Borderline accept: Technically ...
# 3      {'rating': '4: Borderline reject: Technically ...
# 4      {'rating': '6: Weak Accept: Technically solid,...
# ...                                                  ...
# 39365  {'confidence': '4: You are confident in your a...
# 39366  {'confidence': '5: You are absolutely certain ...
# 39369  {'confidence': '4: You are confident in your a...
# 39370  {'confidence': '4: You are confident in your a...
# 39371  {'confidence': '4: You are confident in your a...
#
#                                               signatures     readers  \
# 0      [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]
# 1      [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]
# 2      [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]
# 3      [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]
# 4      [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]
# ...                                                  ...         ...
# 39365  [ICLR.cc/2023/Conference/Paper2809/Reviewer_86ui]  [everyone]
# 39366  [ICLR.cc/2023/Conference/Paper2809/Reviewer_BQAF]  [everyone]
# 39369   [ICLR.cc/2023/Conference/Paper211/Reviewer_Xyj5]  [everyone]
# 39370   [ICLR.cc/2023/Conference/Paper211/Reviewer_6srd]  [everyone]
# 39371   [ICLR.cc/2023/Conference/Paper211/Reviewer_Xnqd]  [everyone]
#
#       nonreaders                                            writers  pdate  \
# 0             []  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN
# 1             []  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN
# 2             []  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN
# 3             []  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN
# 4             []  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN
# ...          ...                                                ...    ...
# 39365         []  [ICLR.cc/2023/Conference, ICLR.cc/2023/Confere...    NaN
# 39366         []  [ICLR.cc/2023/Conference, ICLR.cc/2023/Confere...    NaN
# 39369         []  [ICLR.cc/2023/Conference, ICLR.cc/2023/Confere...    NaN
# 39370         []  [ICLR.cc/2023/Conference, ICLR.cc/2023/Confere...    NaN
# 39371         []  [ICLR.cc/2023/Conference, ICLR.cc/2023/Confere...    NaN
#
#        odate
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 39365    NaN
# 39366    NaN
# 39369    NaN
# 39370    NaN
# 39371    NaN
#
# [24801 rows x 19 columns]

# %%
other_replies_df
# Out:
#                 id original  number          cdate         mdate ddate  \
# 5       pqUNCBau8I     None       7  1659443987292           NaN  None
# 6       RWoipwU7F0     None       1  1661264951443           NaN  None
# 7      n0WgnRZKzkV     None       1  1663188480371           NaN  None
# 12     NyUpol5cxNQ     None       7  1659470031282           NaN  None
# 13     _vFgJkPuefe     None       1  1661589737935           NaN  None
# ...            ...      ...     ...            ...           ...   ...
# 39356   4H5rhjjsHu     None       1  1674241742500           NaN  None
# 39361   R3MosirJNc     None       1  1674241829330           NaN  None
# 39367   Vmd0LRoc-3     None       8  1668817575692  1.668818e+12  None
# 39368   Eefp3ys-qE     None       1  1674241790792           NaN  None
# 39372   MpXmRHoGa4     None       1  1674241828756           NaN  None
#
#               tcdate         tmdate tddate        forum      replyto  \
# 5      1659443987292  1659443987292   None  zzDrPqn57DL  zzDrPqn57DL
# 6      1661264951443  1661264951443   None  zzDrPqn57DL  zzDrPqn57DL
# 7      1663188480371  1663188480371   None  zzDrPqn57DL  zzDrPqn57DL
# 12     1659470031282  1659929414952   None  zz0FC7qBpkh  zz0FC7qBpkh
# 13     1661589737935  1661589737935   None  zz0FC7qBpkh  zz0FC7qBpkh
# ...              ...            ...    ...          ...          ...
# 39356  1674241742500  1674241742500   None  -4DiyBMgv9m  -4DiyBMgv9m
# 39361  1674241829330  1674241829330   None   -2zfgNS917   -2zfgNS917
# 39367  1668817575692  1668817575692   None  -1x2-lp1eZf  -1x2-lp1eZf
# 39368  1674241790792  1674241790792   None  -1x2-lp1eZf  -1x2-lp1eZf
# 39372  1674241828756  1674241828756   None   -0tPmzgXS5   -0tPmzgXS5
#
#                                               invitation  \
# 5      NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 6      NeurIPS.cc/2022/Conference/Paper2310/-/Meta_Re...
# 7        NeurIPS.cc/2022/Conference/Paper2310/-/Decision
# 12     NeurIPS.cc/2022/Conference/Paper12079/-/Offici...
# 13     NeurIPS.cc/2022/Conference/Paper12079/-/Meta_R...
# ...                                                  ...
# 39356       ICLR.cc/2023/Conference/Paper6214/-/Decision
# 39361        ICLR.cc/2023/Conference/Paper143/-/Decision
# 39367  ICLR.cc/2023/Conference/Paper2809/-/Official_C...
# 39368       ICLR.cc/2023/Conference/Paper2809/-/Decision
# 39372        ICLR.cc/2023/Conference/Paper211/-/Decision
#
#                                                  content  \
# 5      {'title': '[Summary of Response] Thanks all re...
# 6      {'metareview': 'The paper proposes a method to...
# 7      {'title': 'Paper Decision', 'decision': 'Accep...
# 12     {'title': 'Common response to all reviewers', ...
# 13     {'metareview': 'The paper theoretically consid...
# ...                                                  ...
# 39356  {'title': 'Paper Decision', 'decision': 'Rejec...
# 39361  {'title': 'Paper Decision', 'decision': 'Accep...
# 39367  {'title': 'Please respond to author rebuttal',...
# 39368  {'title': 'Paper Decision', 'decision': 'Rejec...
# 39372  {'title': 'Paper Decision', 'decision': 'Rejec...
#
#                                               signatures     readers  \
# 5         [NeurIPS.cc/2022/Conference/Paper2310/Authors]  [everyone]
# 6      [NeurIPS.cc/2022/Conference/Paper2310/Area_Cha...  [everyone]
# 7            [NeurIPS.cc/2022/Conference/Program_Chairs]  [everyone]
# 12       [NeurIPS.cc/2022/Conference/Paper12079/Authors]  [everyone]
# 13     [NeurIPS.cc/2022/Conference/Paper12079/Area_Ch...  [everyone]
# ...                                                  ...         ...
# 39356           [ICLR.cc/2023/Conference/Program_Chairs]  [everyone]
# 39361           [ICLR.cc/2023/Conference/Program_Chairs]  [everyone]
# 39367  [ICLR.cc/2023/Conference/Paper2809/Area_Chair_...  [everyone]
# 39368           [ICLR.cc/2023/Conference/Program_Chairs]  [everyone]
# 39372           [ICLR.cc/2023/Conference/Program_Chairs]  [everyone]
#
#       nonreaders                                            writers  pdate  \
# 5             []  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN
# 6             []  [NeurIPS.cc/2022/Conference/Program_Chairs, Ne...    NaN
# 7             []        [NeurIPS.cc/2022/Conference/Program_Chairs]    NaN
# 12            []  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN
# 13            []  [NeurIPS.cc/2022/Conference/Program_Chairs, Ne...    NaN
# ...          ...                                                ...    ...
# 39356         []           [ICLR.cc/2023/Conference/Program_Chairs]    NaN
# 39361         []           [ICLR.cc/2023/Conference/Program_Chairs]    NaN
# 39367         []  [ICLR.cc/2023/Conference, ICLR.cc/2023/Confere...    NaN
# 39368         []           [ICLR.cc/2023/Conference/Program_Chairs]    NaN
# 39372         []           [ICLR.cc/2023/Conference/Program_Chairs]    NaN
#
#        odate
# 5        NaN
# 6        NaN
# 7        NaN
# 12       NaN
# 13       NaN
# ...      ...
# 39356    NaN
# 39361    NaN
# 39367    NaN
# 39368    NaN
# 39372    NaN
#
# [14572 rows x 19 columns]

# %%
_example_review = review_df[review_df['replyto'] == paper_df.iloc[0]['id']]

print("replies to paper id: ", paper_df.iloc[0]['id'])
display(_example_review)

print("")
print("content of a review:")
display(_example_review.iloc[0]['content'])
# Out:
# replies to paper id:  zzDrPqn57DL
#             id original  number          cdate  mdate ddate         tcdate  \
# 0   VrENUT1h6-     None       1  1656944073004    NaN  None  1656944073004
# 1  B8g021IaaAm     None       2  1657487808768    NaN  None  1657487808768
# 2  HNAOCsCSzZw     None       3  1657585011273    NaN  None  1657585011273
# 3   uVn6Us0aP_     None       4  1657587291965    NaN  None  1657587291965
# 4  Hd6Ce57Ircd     None       5  1658042263683    NaN  None  1658042263683
#
#           tmdate tddate        forum      replyto  \
# 0  1656944073004   None  zzDrPqn57DL  zzDrPqn57DL
# 1  1660833391821   None  zzDrPqn57DL  zzDrPqn57DL
# 2  1657585011273   None  zzDrPqn57DL  zzDrPqn57DL
# 3  1657587291965   None  zzDrPqn57DL  zzDrPqn57DL
# 4  1658049110257   None  zzDrPqn57DL  zzDrPqn57DL
#
#                                           invitation  \
# 0  NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 1  NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 2  NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 3  NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 4  NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
#
#                                              content  \
# 0  {'rating': '7: Accept: Technically solid paper...
# 1  {'rating': '5: Borderline accept: Technically ...
# 2  {'rating': '5: Borderline accept: Technically ...
# 3  {'rating': '4: Borderline reject: Technically ...
# 4  {'rating': '6: Weak Accept: Technically solid,...
#
#                                           signatures     readers nonreaders  \
# 0  [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]         []
# 1  [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]         []
# 2  [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]         []
# 3  [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]         []
# 4  [NeurIPS.cc/2022/Conference/Paper2310/Reviewer...  [everyone]         []
#
#                                              writers  pdate  odate
# 0  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN    NaN
# 1  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN    NaN
# 2  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN    NaN
# 3  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN    NaN
# 4  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN    NaN
# content of a review:
# {'rating': '7: Accept: Technically solid paper, with high impact on at least one sub-area, or moderate-to-high impact on more than one areas, with good-to-excellent evaluation, resources, reproducibility, and no unaddressed ethical considerations.',
#  'confidence': '3: You are fairly confident in your assessment. It is possible that you did not understand some parts of the submission or that you are unfamiliar with some pieces of related work. Math/other details were not carefully checked.',
#  'summary': 'Towards the problem of current methods tend to fail at situations where hardware malfunctions, this paper presents a simple yet effective LiDAR-Camera fusion framework, namely BEVFusion. By disentangling camera pipeline from LiDAR network and using a dynamic fusion module, BEVFusion achieves SOTA performance and shows robustness against LiDAR or camera malfunction at the same time. An effective modification on the camera pipeline is also proposed to boost the final performance.',
#  'strengths_and_weaknesses': '## Strength\n1. The paper is well written and easy to read.\n2. Robustness of autonomous driving algorithms should be paid more attention to. This paper raises the issue and makes the attempt to addressing it.\n3. Thorough experiments are performed. Claims are well-supported. SOTA performance is achieved on both normal and robust settings of nuScenes.\n4. The clean design of the framework makes it easy to use any camera or LiDAR framework.\n\n\n## Weaknesses\n1. It is nice to see a simple yet effective module (dynamic fusion module) being proposed. But it would be nicer to provide some insights and analysis into the design itself. For example, by analyzing how would the fusion module work when facing incomplete LiDAR or camera inputs, we might gain some insights into the module design of CSF and AFS.\n2. The experiments section does not provide runtime analysis, like inference time and memory footprint, and its comparison with other methods.',
#  'questions': '1. How does the baseline method in Table 7 fuse the features?\n2. This does not affect my rating to the paper. Just out of curious, would BEVFusion still works when facing both camera and LiDAR malfunction?',
#  'limitations': 'The potential negative social impact is well discussed. But the limitation should be discussed more. For example, would the late-fusion style misses the opportunity to fuse intermediate LiDAR and camera features, and thus makes the pipeline suffer potential performance drop?',
#  'ethics_flag': 'No',
#  'ethics_review_area': [],
#  'soundness': '3 good',
#  'presentation': '3 good',
#  'contribution': '3 good',
#  'code_of_conduct': 'Yes'}

# %%
_example_other_reply = other_replies_df[other_replies_df['replyto'] == paper_df.iloc[0]['id']]
_example_other_reply.reset_index(drop=True, inplace=True)
print("replies to paper id: ", paper_df.iloc[0]['id'])

_example_other_reply
# Out:
# replies to paper id:  zzDrPqn57DL
#             id original  number          cdate  mdate ddate         tcdate  \
# 0   pqUNCBau8I     None       7  1659443987292    NaN  None  1659443987292
# 1   RWoipwU7F0     None       1  1661264951443    NaN  None  1661264951443
# 2  n0WgnRZKzkV     None       1  1663188480371    NaN  None  1663188480371
#
#           tmdate tddate        forum      replyto  \
# 0  1659443987292   None  zzDrPqn57DL  zzDrPqn57DL
# 1  1661264951443   None  zzDrPqn57DL  zzDrPqn57DL
# 2  1663188480371   None  zzDrPqn57DL  zzDrPqn57DL
#
#                                           invitation  \
# 0  NeurIPS.cc/2022/Conference/Paper2310/-/Officia...
# 1  NeurIPS.cc/2022/Conference/Paper2310/-/Meta_Re...
# 2    NeurIPS.cc/2022/Conference/Paper2310/-/Decision
#
#                                              content  \
# 0  {'title': '[Summary of Response] Thanks all re...
# 1  {'metareview': 'The paper proposes a method to...
# 2  {'title': 'Paper Decision', 'decision': 'Accep...
#
#                                           signatures     readers nonreaders  \
# 0     [NeurIPS.cc/2022/Conference/Paper2310/Authors]  [everyone]         []
# 1  [NeurIPS.cc/2022/Conference/Paper2310/Area_Cha...  [everyone]         []
# 2        [NeurIPS.cc/2022/Conference/Program_Chairs]  [everyone]         []
#
#                                              writers  pdate  odate
# 0  [NeurIPS.cc/2022/Conference, NeurIPS.cc/2022/C...    NaN    NaN
# 1  [NeurIPS.cc/2022/Conference/Program_Chairs, Ne...    NaN    NaN
# 2        [NeurIPS.cc/2022/Conference/Program_Chairs]    NaN    NaN

# %%
# calculating features for each paper

feature_df = paper_df.iloc[:, [0]].copy()
feature_df.rename(columns={'id': 'paper_id'}, inplace=True)
feature_df
# Out:
#          paper_id
# 0     zzDrPqn57DL
# 1     zz0FC7qBpkh
# 2      zyrBT58h_J
# 3     zvNMzjOizmn
# 4     zuL5OYIBgcV
# ...           ...
# 6615  -4Maz7s3YXz
# 6616  -4DiyBMgv9m
# 6617   -2zfgNS917
# 6618  -1x2-lp1eZf
# 6619   -0tPmzgXS5
#
# [6620 rows x 1 columns]

# %%
# maybe_important_fields = ['title', 'authors', 'keywords', 'TL;DR', 'abstract']

feature_df['title_length'] = paper_df['content'].apply(lambda x: len(x.get('title', '')))
feature_df['abstract_length'] = paper_df['content'].apply(lambda x: len(x.get('abstract', '')))
feature_df['tldr_length'] = paper_df['content'].apply(lambda x: len(x.get('TL;DR', '')))

feature_df['author_count'] = paper_df['content'].apply(lambda x: len(x.get('authors', [])))
feature_df['keyword_count'] = paper_df['content'].apply(lambda x: len(x.get('keywords', [])))

feature_df
# Out:
#          paper_id  title_length  abstract_length  tldr_length  author_count  \
# 0     zzDrPqn57DL            60             1167          141             9
# 1     zz0FC7qBpkh            94             1162          172             2
# 2      zyrBT58h_J            58             1614          146             7
# 3     zvNMzjOizmn            62             1267            0             4
# 4     zuL5OYIBgcV            17             1013            0             4
# ...           ...           ...              ...          ...           ...
# 6615  -4Maz7s3YXz            65             1366          125             2
# 6616  -4DiyBMgv9m            89             1246            0             2
# 6617   -2zfgNS917            75             1497           97             6
# 6618  -1x2-lp1eZf            74             1862          114             7
# 6619   -0tPmzgXS5            46             1197          131             5
#
#       keyword_count
# 0                 3
# 1                 0
# 2                 3
# 3                 3
# 4                 0
# ...             ...
# 6615              5
# 6616              0
# 6617              3
# 6618              3
# 6619              3
#
# [6620 rows x 6 columns]

# %%
# a.iloc[2]['content']['decision']  # eg Accept
# a.iloc[2]['content']['comment']  # eg 'asdf'
# signatures is a list of strings and one of them must have 'Program_Chairs' in it


def get_decision(group_df: 'pd.Series'):
    decision_note = group_df[group_df['invitation'].apply(lambda x: '/Decision' in x)]
    if len(decision_note) == 1:
        decision = decision_note['content'].iloc[0]['decision']
        return 'Accept' in decision
    else:
        display(group_df)
        display(decision_note)
        assert False

def get_comment_length(group_df: 'pd.Series'):
    decision_note = group_df[group_df['invitation'].apply(lambda x: '/Meta' in x)]
    if len(decision_note) == 1:
        metareview = decision_note['content'].iloc[0]['metareview']
        return len(metareview)
    # paper might not have a metareview
    return None


decision_agg = other_replies_df.groupby('replyto').progress_apply(
    lambda group: pd.Series(
        {
            # we are working on a group.
            'is_accepted': get_decision(group),
            'metareview_length': get_comment_length(group),
            # you can add more here
        }),
).reset_index()

decision_agg
# Out:
# 100%|██████████| 6620/6620 [00:01<00:00, 3711.43it/s]
#           replyto  is_accepted  metareview_length
# 0     --aQNMdJc9x         True              753.0
# 1     --fdtqo-iKM         True              436.0
# 2      -0tPmzgXS5        False                NaN
# 3     -1x2-lp1eZf        False                NaN
# 4      -2zfgNS917         True                NaN
# ...           ...          ...                ...
# 6615   zyrBT58h_J         True              197.0
# 6616  zz0FC7qBpkh         True              828.0
# 6617  zzDrPqn57DL         True             1033.0
# 6618   zzL_5WoI3I        False                NaN
# 6619   zzqBoIFOQ1         True                NaN
#
# [6620 rows x 3 columns]

# %%
decision_agg = decision_agg.rename(columns={'replyto': 'paper_id'})
feature_df = feature_df.merge(decision_agg, on='paper_id', how='left')
feature_df
# Out:
#          paper_id  title_length  abstract_length  tldr_length  author_count  \
# 0     zzDrPqn57DL            60             1167          141             9
# 1     zz0FC7qBpkh            94             1162          172             2
# 2      zyrBT58h_J            58             1614          146             7
# 3     zvNMzjOizmn            62             1267            0             4
# 4     zuL5OYIBgcV            17             1013            0             4
# ...           ...           ...              ...          ...           ...
# 6615  -4Maz7s3YXz            65             1366          125             2
# 6616  -4DiyBMgv9m            89             1246            0             2
# 6617   -2zfgNS917            75             1497           97             6
# 6618  -1x2-lp1eZf            74             1862          114             7
# 6619   -0tPmzgXS5            46             1197          131             5
#
#       keyword_count  is_accepted  metareview_length
# 0                 3         True             1033.0
# 1                 0         True              828.0
# 2                 3         True              197.0
# 3                 3         True              650.0
# 4                 0         True              980.0
# ...             ...          ...                ...
# 6615              5        False                NaN
# 6616              0        False                NaN
# 6617              3         True                NaN
# 6618              3        False                NaN
# 6619              3        False                NaN
#
# [6620 rows x 8 columns]

# %%
review_df.iloc[18046]['content']
# Out:
# {'confidence': '3: You are fairly confident in your assessment. It is possible that you did not understand some parts of the submission or that you are unfamiliar with some pieces of related work. Math/other details were not carefully checked.',
#  'summary_of_the_paper': 'This work demonstrates the natural emergence of sparsity in commonly used Transformer models. \n\nThis paper proposed  Top-k thresholding to enforce sparsity, which brings robustness of training with erroneous annotations, less sensitivity to input noise/perturbation, and better confidence calibration of the predictions.',
#  'strength_and_weaknesses': 'Strength:\n(1)This paper observed the sparsity in Transformers and this sparsity is emergent without any explicit design.\n\n(2) This paper found that sparsity in Transformers is a prevalent phenomenon, and can improve efficiency, robustness and calibration.\n\n(3) This paper further presented Top-k Transformer, a simple modification to Transformer architecture that allows control on the sparsity level for all model inputs throughout training.\n\nWeakness:\n(1) This paper only shows sparsity on the classification task. Is the sparsity existing for downstream tasks? such as detection and segmentation.\n\n(2) Tab 1 shows that Top-128 ViT is on par with ViT for natural accuracy while is significantly better for model robustness and calibration. How about the other Top-k results? (please move some experiments from the appendix). \n',
#  'clarity,_quality,_novelty_and_reproducibility': "This paper's motivation is based on statistical observation. The analysis is insightful and well supported by some experiments.\nAs T5 and ViT are public available models, this paper is reproducible.\n",
#  'summary_of_the_review': "This paper observed the sparsity in Transformers and proposed Top-k thresholding to enforce sparsity. Based on the proposed method, the efficiency, robustness and calibration are improved. However, this paper only considered the classification task, and I'd like to see the sparsity existing in the downstream tasks. ",
#  'correctness': '3: Some of the paper’s claims have minor issues. A few statements are not well-supported, or require small changes to be made correct.',
#  'technical_novelty_and_significance': '3: The contributions are significant and somewhat new. Aspects of the contributions exist in prior work.',
#  'empirical_novelty_and_significance': '3: The contributions are significant and somewhat new. Aspects of the contributions exist in prior work.',
#  'flag_for_ethics_review': ['NO.'],
#  'details_of_ethics_concerns': 'No ethics concerns.',
#  'recommendation': '8: accept, good paper'}

# %%
# first we define the helper and main functions

import re


def _extract_numeric_prefix(maybe_string: object) -> int:
    """
    Extracts the leading integer from a string.
    If no integer is found, returns NaN.
    """
    string = str(maybe_string)
    match = re.match(r'^(\d+)', string.strip())
    return int(match.group(1)) if match else np.nan


def numeric_prefix_agg(series: 'pd.Series', fieldname: str, agg_func: callable):
    field_values = series.apply(lambda x: _extract_numeric_prefix(x.get(fieldname)) if isinstance(x, dict) else None)

    if field_values.isnull().all():
        return np.nan  # if cannot extract numeric prefix from any value, return NaN
    return agg_func(field_values)


# then we agg it. Note that this functions are applied to the 'content' field of the reviews.
agg_functions_on_df = {
    'review_count': 'count',  # Count reviews
    #          example entry. The dict will have (key,value) pairs like this:
    #          'recommendation_nanmean': lambda s: numeric_prefix_agg(s, 'rating', np.nanmean),
}


fields = ['confidence', 'correctness', 'technical_novelty_and_significance',
          'empirical_novelty_and_significance', 'recommendation']
agg_functions = [np.nanmean, np.nanstd, 
                 np.nanmin, np.nanmax, np.nanmedian, np.nansum, np.nanvar, np.nanprod
                 ]

# add the aggregation functions to the dictionary
for field in fields:
    for func in agg_functions:
        agg_functions_on_df[f'review_{field}_{func.__name__}'] = lambda s, field=field, func=func: numeric_prefix_agg(s, field, func)


# this is just 'review_df.groupby('replyto').agg(agg_functions_on_df).reset_index()' but I want tqdm. Thus the complexity.
review_agg = review_df.groupby('replyto').progress_apply(
    lambda group: group['content'].agg(agg_functions_on_df)
).reset_index()
review_agg
# Out:
# 100%|██████████| 6620/6620 [00:25<00:00, 257.66it/s]
# content      replyto  review_count  review_confidence_nanmean  \
# 0        --aQNMdJc9x           5.0                   3.000000
# 1        --fdtqo-iKM           4.0                   3.500000
# 2         -0tPmzgXS5           3.0                   4.000000
# 3        -1x2-lp1eZf           5.0                   4.200000
# 4         -2zfgNS917           4.0                   3.500000
# ...              ...           ...                        ...
# 6615      zyrBT58h_J           3.0                   3.333333
# 6616     zz0FC7qBpkh           4.0                   3.250000
# 6617     zzDrPqn57DL           5.0                   3.400000
# 6618      zzL_5WoI3I           3.0                   3.666667
# 6619      zzqBoIFOQ1           4.0                   3.500000
#
# content  review_confidence_nanstd  review_confidence_nanmin  \
# 0                        0.000000                       3.0
# 1                        0.866025                       2.0
# 2                        0.000000                       4.0
# 3                        0.400000                       4.0
# 4                        0.500000                       3.0
# ...                           ...                       ...
# 6615                     0.471405                       3.0
# 6616                     0.433013                       3.0
# 6617                     0.489898                       3.0
# 6618                     0.471405                       3.0
# 6619                     0.500000                       3.0
#
# content  review_confidence_nanmax  review_confidence_nanmedian  \
# 0                             3.0                          3.0
# 1                             4.0                          4.0
# 2                             4.0                          4.0
# 3                             5.0                          4.0
# 4                             4.0                          3.5
# ...                           ...                          ...
# 6615                          4.0                          3.0
# 6616                          4.0                          3.0
# 6617                          4.0                          3.0
# 6618                          4.0                          4.0
# 6619                          4.0                          3.5
#
# content  review_confidence_nansum  review_confidence_nanvar  \
# 0                            15.0                  0.000000
# 1                            14.0                  0.750000
# 2                            12.0                  0.000000
# 3                            21.0                  0.160000
# 4                            14.0                  0.250000
# ...                           ...                       ...
# 6615                         10.0                  0.222222
# 6616                         13.0                  0.187500
# 6617                         17.0                  0.240000
# 6618                         11.0                  0.222222
# 6619                         14.0                  0.250000
#
# content  review_confidence_nanprod  ...  \
# 0                            243.0  ...
# 1                            128.0  ...
# 2                             64.0  ...
# 3                           1280.0  ...
# 4                            144.0  ...
# ...                            ...  ...
# 6615                          36.0  ...
# 6616                         108.0  ...
# 6617                         432.0  ...
# 6618                          48.0  ...
# 6619                         144.0  ...
#
# content  review_empirical_novelty_and_significance_nanvar  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                0.222222
# 3                                                0.240000
# 4                                                0.222222
# ...                                                   ...
# 6615                                                  NaN
# 6616                                                  NaN
# 6617                                                  NaN
# 6618                                             0.222222
# 6619                                             0.187500
#
# content  review_empirical_novelty_and_significance_nanprod  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                     18.0
# 3                                                     72.0
# 4                                                     18.0
# ...                                                    ...
# 6615                                                   NaN
# 6616                                                   NaN
# 6617                                                   NaN
# 6618                                                  12.0
# 6619                                                  24.0
#
# content  review_recommendation_nanmean  review_recommendation_nanstd  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                             5.666667                      0.471405
# 3                             3.600000                      1.200000
# 4                             6.500000                      0.866025
# ...                                ...                           ...
# 6615                               NaN                           NaN
# 6616                               NaN                           NaN
# 6617                               NaN                           NaN
# 6618                          5.666667                      2.054805
# 6619                          6.500000                      0.866025
#
# content  review_recommendation_nanmin  review_recommendation_nanmax  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 5.0                           6.0
# 3                                 3.0                           6.0
# 4                                 6.0                           8.0
# ...                               ...                           ...
# 6615                              NaN                           NaN
# 6616                              NaN                           NaN
# 6617                              NaN                           NaN
# 6618                              3.0                           8.0
# 6619                              6.0                           8.0
#
# content  review_recommendation_nanmedian  review_recommendation_nansum  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    6.0                          17.0
# 3                                    3.0                          18.0
# 4                                    6.0                          26.0
# ...                                  ...                           ...
# 6615                                 NaN                           NaN
# 6616                                 NaN                           NaN
# 6617                                 NaN                           NaN
# 6618                                 6.0                          17.0
# 6619                                 6.0                          26.0
#
# content  review_recommendation_nanvar  review_recommendation_nanprod
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                            0.222222                          180.0
# 3                            1.440000                          486.0
# 4                            0.750000                         1728.0
# ...                               ...                            ...
# 6615                              NaN                            NaN
# 6616                              NaN                            NaN
# 6617                              NaN                            NaN
# 6618                         4.222222                          144.0
# 6619                         0.750000                         1728.0
#
# [6620 rows x 42 columns]

# %%
review_agg.rename(columns={'replyto': 'paper_id'}, inplace=True)
feature_df = feature_df.merge(review_agg, on='paper_id', how='left')
feature_df
# Out:
#          paper_id  title_length  abstract_length  tldr_length  author_count  \
# 0     zzDrPqn57DL            60             1167          141             9
# 1     zz0FC7qBpkh            94             1162          172             2
# 2      zyrBT58h_J            58             1614          146             7
# 3     zvNMzjOizmn            62             1267            0             4
# 4     zuL5OYIBgcV            17             1013            0             4
# ...           ...           ...              ...          ...           ...
# 6615  -4Maz7s3YXz            65             1366          125             2
# 6616  -4DiyBMgv9m            89             1246            0             2
# 6617   -2zfgNS917            75             1497           97             6
# 6618  -1x2-lp1eZf            74             1862          114             7
# 6619   -0tPmzgXS5            46             1197          131             5
#
#       keyword_count  is_accepted  metareview_length  review_count  \
# 0                 3         True             1033.0           5.0
# 1                 0         True              828.0           4.0
# 2                 3         True              197.0           3.0
# 3                 3         True              650.0           3.0
# 4                 0         True              980.0           5.0
# ...             ...          ...                ...           ...
# 6615              5        False                NaN           3.0
# 6616              0        False                NaN           5.0
# 6617              3         True                NaN           4.0
# 6618              3        False                NaN           5.0
# 6619              3        False                NaN           3.0
#
#       review_confidence_nanmean  ...  \
# 0                      3.400000  ...
# 1                      3.250000  ...
# 2                      3.333333  ...
# 3                      3.666667  ...
# 4                      4.200000  ...
# ...                         ...  ...
# 6615                   4.000000  ...
# 6616                   3.000000  ...
# 6617                   3.500000  ...
# 6618                   4.200000  ...
# 6619                   4.000000  ...
#
#       review_empirical_novelty_and_significance_nanvar  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 6615                                          0.000000
# 6616                                          0.250000
# 6617                                          0.222222
# 6618                                          0.240000
# 6619                                          0.222222
#
#       review_empirical_novelty_and_significance_nanprod  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6615                                                2.0
# 6616                                                6.0
# 6617                                               18.0
# 6618                                               72.0
# 6619                                               18.0
#
#       review_recommendation_nanmean  review_recommendation_nanstd  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 6615                       3.666667                      0.942809
# 6616                       3.800000                      1.939072
# 6617                       6.500000                      0.866025
# 6618                       3.600000                      1.200000
# 6619                       5.666667                      0.471405
#
#       review_recommendation_nanmin  review_recommendation_nanmax  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 6615                           3.0                           5.0
# 6616                           1.0                           6.0
# 6617                           6.0                           8.0
# 6618                           3.0                           6.0
# 6619                           5.0                           6.0
#
#       review_recommendation_nanmedian  review_recommendation_nansum  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 6615                              3.0                          11.0
# 6616                              3.0                          19.0
# 6617                              6.0                          26.0
# 6618                              3.0                          18.0
# 6619                              6.0                          17.0
#
#       review_recommendation_nanvar  review_recommendation_nanprod
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 6615                      0.888889                           45.0
# 6616                      3.760000                          324.0
# 6617                      0.750000                         1728.0
# 6618                      1.440000                          486.0
# 6619                      0.222222                          180.0
#
# [6620 rows x 49 columns]

# %%
with open('feature_df.pkl', 'wb') as f:
    pickle.dump(feature_df, f)
