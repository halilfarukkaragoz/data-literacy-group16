# %%
import sys
import os
from pathlib import Path

pwd  = Path(os.getcwd())
sys.path.append(str(pwd.parent.parent)) # needed to use "koray" module

# %%
import pandas as pd
import numpy as np

# %%
from koray.feature_calculation.util import get_features


conference_invitations = [
# 'NeurIPS.cc/2022/Conference/-/Blind_Submission',
'ICLR.cc/2023/Conference/-/Blind_Submission',
# 'ICLR.cc/2022/Conference/-/Blind_Submission',
# 'ICLR.cc/2021/Conference/-/Blind_Submission',
]

feature_df = list(get_features(conference_invitations, disable_cache=True))
# feature_df = list(get_features(conference_invitations, disable_cache=False))
df = pd.concat(feature_df)
df
# Out:
# Calculating features for ICLR.cc/2023/Conference/-/Blind_Submission (1/1)
# Output()
# ✔ Successfully loaded dataframes
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# /Users/koray/data-literacy-group16/koray/feature_calculation/paper_features.py:117: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# /Users/koray/data-literacy-group16/koray/feature_calculation/paper_features.py:117: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# /Users/koray/data-literacy-group16/koray/feature_calculation/paper_features.py:117: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# /Users/koray/data-literacy-group16/koray/feature_calculation/paper_features.py:117: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
# ✔ Successfully calculated features
# /Users/koray/data-literacy-group16/koray/feature_calculation/paper_features.py:117: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.feature_df[col] = self.feature_df[col].astype(dtype)
#          paper_id  abstract_length  author_count  is_accepted  keyword_count  \
# 0      -0tPmzgXS5              1.0           5.0        False            3.0
# 1     -1x2-lp1eZf              1.0           7.0        False            3.0
# 2      -2zfgNS917              1.0           6.0         True            3.0
# 3     -4DiyBMgv9m              1.0           2.0        False            NaN
# 4     -4Maz7s3YXz              1.0           2.0        False            5.0
# ...           ...              ...           ...          ...            ...
# 3791   zufPou5foW              1.0           5.0        False            4.0
# 3792  zyLVMgsZ0U_              1.0           6.0         True            6.0
# 3793   zyfEWkV6it              1.0           5.0        False            3.0
# 3794   zzL_5WoI3I              1.0           2.0        False            3.0
# 3795   zzqBoIFOQ1              1.0           3.0         True            3.0
#
#      metareview_length  reviewer_confidence_nanmax  \
# 0                 None                         4.0
# 1                 None                         5.0
# 2                 None                         4.0
# 3                 None                         4.0
# 4                 None                         4.0
# ...                ...                         ...
# 3791              None                         4.0
# 3792              None                         4.0
# 3793              None                         5.0
# 3794              None                         4.0
# 3795              None                         4.0
#
#       reviewer_confidence_nanmean  reviewer_confidence_nanmedian  \
# 0                        4.000000                            4.0
# 1                        4.200000                            4.0
# 2                        3.500000                            3.5
# 3                        3.000000                            3.0
# 4                        4.000000                            4.0
# ...                           ...                            ...
# 3791                     3.750000                            4.0
# 3792                     3.250000                            3.0
# 3793                     4.000000                            4.5
# 3794                     3.666667                            4.0
# 3795                     3.500000                            3.5
#
#       reviewer_confidence_nanmin  ...  reviewer_recommendation_nanstd  \
# 0                            4.0  ...                        0.471405
# 1                            4.0  ...                        1.200000
# 2                            3.0  ...                        0.866025
# 3                            2.0  ...                        1.939072
# 4                            4.0  ...                        0.942809
# ...                          ...  ...                             ...
# 3791                         3.0  ...                        1.299038
# 3792                         3.0  ...                        0.000000
# 3793                         2.0  ...                        1.247219
# 3794                         3.0  ...                        2.054805
# 3795                         3.0  ...                        0.866025
#
#       reviewer_recommendation_nanvar  \
# 0                           0.222222
# 1                           1.440000
# 2                           0.750000
# 3                           3.760000
# 4                           0.888889
# ...                              ...
# 3791                        1.687500
# 3792                        0.000000
# 3793                        1.555556
# 3794                        4.222222
# 3795                        0.750000
#
#       reviewer_technical_novelty_and_significance_nanmax  \
# 0                                                   3.0
# 1                                                   3.0
# 2                                                   3.0
# 3                                                   3.0
# 4                                                   3.0
# ...                                                 ...
# 3791                                                2.0
# 3792                                                4.0
# 3793                                                3.0
# 3794                                                4.0
# 3795                                                3.0
#
#       reviewer_technical_novelty_and_significance_nanmean  \
# 0                                              2.666667
# 1                                              2.400000
# 2                                              2.250000
# 3                                              2.800000
# 4                                              2.666667
# ...                                                 ...
# 3791                                           2.000000
# 3792                                           3.500000
# 3793                                           2.166667
# 3794                                           3.000000
# 3795                                           3.000000
#
#       reviewer_technical_novelty_and_significance_nanmedian  \
# 0                                                   3.0
# 1                                                   2.0
# 2                                                   2.0
# 3                                                   3.0
# 4                                                   3.0
# ...                                                 ...
# 3791                                                2.0
# 3792                                                3.5
# 3793                                                2.0
# 3794                                                3.0
# 3795                                                3.0
#
#       reviewer_technical_novelty_and_significance_nanmin  \
# 0                                                   2.0
# 1                                                   2.0
# 2                                                   2.0
# 3                                                   2.0
# 4                                                   2.0
# ...                                                 ...
# 3791                                                2.0
# 3792                                                3.0
# 3793                                                1.0
# 3794                                                2.0
# 3795                                                3.0
#
#       reviewer_technical_novelty_and_significance_nanstd  \
# 0                                              0.471405
# 1                                              0.489898
# 2                                              0.433013
# 3                                              0.400000
# 4                                              0.471405
# ...                                                 ...
# 3791                                           0.000000
# 3792                                           0.500000
# 3793                                           0.687184
# 3794                                           0.816497
# 3795                                           0.000000
#
#       reviewer_technical_novelty_and_significance_nanvar  title_length  \
# 0                                              0.222222            1.0
# 1                                              0.240000            1.0
# 2                                              0.187500            1.0
# 3                                              0.160000            1.0
# 4                                              0.222222            1.0
# ...                                                 ...            ...
# 3791                                           0.000000            1.0
# 3792                                           0.250000            1.0
# 3793                                           0.472222            1.0
# 3794                                           0.666667            1.0
# 3795                                           0.000000            1.0
#
#       tldr_length
# 0             1.0
# 1             1.0
# 2             1.0
# 3             NaN
# 4             1.0
# ...           ...
# 3791          NaN
# 3792          1.0
# 3793          NaN
# 3794          1.0
# 3795          1.0
#
# [3796 rows x 38 columns]

# %%
df.dtypes
# Out:
# paper_id                                                  object
# abstract_length                                          float64
# author_count                                             float64
# is_accepted                                                 bool
# keyword_count                                            float64
# metareview_length                                         object
# reviewer_confidence_nanmax                               float64
# reviewer_confidence_nanmean                              float64
# reviewer_confidence_nanmedian                            float64
# reviewer_confidence_nanmin                               float64
# reviewer_confidence_nanstd                               float64
# reviewer_confidence_nanvar                               float64
# reviewer_correctness_nanmax                              float64
# reviewer_correctness_nanmean                             float64
# reviewer_correctness_nanmedian                           float64
# reviewer_correctness_nanmin                              float64
# reviewer_correctness_nanstd                              float64
# reviewer_correctness_nanvar                              float64
# reviewer_empirical_novelty_and_significance_nanmax       float64
# reviewer_empirical_novelty_and_significance_nanmean      float64
# reviewer_empirical_novelty_and_significance_nanmedian    float64
# reviewer_empirical_novelty_and_significance_nanmin       float64
# reviewer_empirical_novelty_and_significance_nanstd       float64
# reviewer_empirical_novelty_and_significance_nanvar       float64
# reviewer_recommendation_nanmax                           float64
# reviewer_recommendation_nanmean                          float64
# reviewer_recommendation_nanmedian                        float64
# reviewer_recommendation_nanmin                           float64
# reviewer_recommendation_nanstd                           float64
# reviewer_recommendation_nanvar                           float64
# reviewer_technical_novelty_and_significance_nanmax       float64
# reviewer_technical_novelty_and_significance_nanmean      float64
# reviewer_technical_novelty_and_significance_nanmedian    float64
# reviewer_technical_novelty_and_significance_nanmin       float64
# reviewer_technical_novelty_and_significance_nanstd       float64
# reviewer_technical_novelty_and_significance_nanvar       float64
# title_length                                             float64
# tldr_length                                              float64
# dtype: object

# %%
# columns that have numerical values
numerical_columns = [col for col in df.columns if df[col].dtype in [np.float64, np.int64]]
numerical_columns
# Out:
# ['abstract_length',
#  'author_count',
#  'keyword_count',
#  'reviewer_confidence_nanmax',
#  'reviewer_confidence_nanmean',
#  'reviewer_confidence_nanmedian',
#  'reviewer_confidence_nanmin',
#  'reviewer_confidence_nanstd',
#  'reviewer_confidence_nanvar',
#  'reviewer_correctness_nanmax',
#  'reviewer_correctness_nanmean',
#  'reviewer_correctness_nanmedian',
#  'reviewer_correctness_nanmin',
#  'reviewer_correctness_nanstd',
#  'reviewer_correctness_nanvar',
#  'reviewer_empirical_novelty_and_significance_nanmax',
#  'reviewer_empirical_novelty_and_significance_nanmean',
#  'reviewer_empirical_novelty_and_significance_nanmedian',
#  'reviewer_empirical_novelty_and_significance_nanmin',
#  'reviewer_empirical_novelty_and_significance_nanstd',
#  'reviewer_empirical_novelty_and_significance_nanvar',
#  'reviewer_recommendation_nanmax',
#  'reviewer_recommendation_nanmean',
#  'reviewer_recommendation_nanmedian',
#  'reviewer_recommendation_nanmin',
#  'reviewer_recommendation_nanstd',
#  'reviewer_recommendation_nanvar',
#  'reviewer_technical_novelty_and_significance_nanmax',
#  'reviewer_technical_novelty_and_significance_nanmean',
#  'reviewer_technical_novelty_and_significance_nanmedian',
#  'reviewer_technical_novelty_and_significance_nanmin',
#  'reviewer_technical_novelty_and_significance_nanstd',
#  'reviewer_technical_novelty_and_significance_nanvar',
#  'title_length',
#  'tldr_length']
