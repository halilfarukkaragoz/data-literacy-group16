# %%
import pandas as pd 
import os
from pathlib import Path

import numpy as np

# %%
pwd  = Path(os.getcwd())
pwd
# Out:
# PosixPath('/Users/koray/data-literacy-group13/data_analysis')

# %%
dataset_pkl = "ICLR.cc-2023-Conference-features.pkl"

pkl_path = pwd.parent / "data" / dataset_pkl
df = pd.read_pickle(pkl_path)
df
# Out:
#                                                   title  \
# 0     Guiding Safe Exploration with Weakest Precondi...
# 1     An Adaptive Entropy-Regularization Framework f...
# 2         AutoSparse: Towards Automated Sparse Training
# 3     Sampling is as easy as learning the score: the...
# 4     RoCourseNet: Distributionally Robust Training ...
# ...                                                 ...
# 3791  Towards Understanding Robust Memorization in A...
# 3792  Identifying Phase Transition Thresholds of Per...
# 3793  BEVDistill: Cross-Modal BEV Distillation for M...
# 3794  Rethinking Deep Spiking Neural Networks: A Mul...
# 3795     Probing into Overfitting for Video Recognition
#
#                                                keywords               cdate  \
# 0     [reinforcement learning,  safe learning,  safe... 2022-09-22 14:36:24
# 1     [Multi-Agent Reinforcement Learning,  Entropy ... 2022-09-22 14:33:17
# 2          [sparsity,  sparse training,  deep learning] 2022-09-22 14:32:39
# 3     [diffusion models,  score-based generative mod... 2022-09-22 14:40:10
# 4     [Counterfactual Explanation,  Algorithmic Reco... 2022-09-22 14:38:43
# ...                                                 ...                 ...
# 3791  [adversarial robustness,  adversarial training... 2022-09-22 14:35:25
# 3792                                                 [] 2022-09-22 14:42:21
# 3793  [object detection,  3d detection,  BEV percept... 2022-09-22 14:30:15
# 3794  [spiking neural network,  multi-layer perceptr... 2022-09-22 14:35:28
# 3795  [Action Recognition,  Data Augmentation,  Over... 2022-09-22 14:30:24
#
#                   tmdate  decision_boolean  reviewer1_flag_for_ethics_review  \
# 0    2024-11-25 10:13:40              True                             False
# 1    2023-02-14 00:28:54             False                             False
# 2    2023-02-14 00:29:06             False                             False
# 3    2023-02-14 00:27:00              True                             False
# 4    2024-11-25 10:12:40             False                             False
# ...                  ...               ...                               ...
# 3791 2023-02-14 00:28:19             False                             False
# 3792 2023-02-14 00:26:26             False                             False
# 3793 2024-11-25 10:16:48              True                             False
# 3794 2023-02-14 00:28:18             False                             False
# 3795 2023-02-14 00:29:46             False                             False
#
#       reviewer2_flag_for_ethics_review reviewer3_flag_for_ethics_review  \
# 0                                False                            False
# 1                                False                            False
# 2                                False                            False
# 3                                False                            False
# 4                                False                            False
# ...                                ...                              ...
# 3791                             False                            False
# 3792                             False                            False
# 3793                             False                            False
# 3794                             False                            False
# 3795                             False                            False
#
#      reviewer4_flag_for_ethics_review  reviewer1_recommendation  ...  \
# 0                               False                         6  ...
# 1                                 NaN                         3  ...
# 2                               False                         5  ...
# 3                               False                         8  ...
# 4                               False                         3  ...
# ...                               ...                       ...  ...
# 3791                              NaN                         3  ...
# 3792                            False                         1  ...
# 3793                            False                         6  ...
# 3794                            False                         6  ...
# 3795                              NaN                         6  ...
#
#         reviewer2_tmdate     reviewer3_cdate    reviewer3_tmdate  \
# 0    2022-10-25 00:42:31 2022-10-26 00:04:46 2022-10-26 00:04:46
# 1    2022-10-23 18:43:07 2022-10-24 22:26:06 2022-10-24 22:26:06
# 2    2022-12-05 02:01:28 2022-10-27 05:32:06 2022-10-27 05:32:06
# 3    2022-10-24 02:13:45 2022-10-25 14:35:52 2022-10-25 14:45:19
# 4    2022-10-24 04:04:13 2022-10-24 23:15:45 2022-10-24 23:15:45
# ...                  ...                 ...                 ...
# 3791 2022-10-19 22:52:33 2022-10-25 19:10:12 2022-10-25 22:06:07
# 3792 2022-10-25 09:40:26 2022-10-25 21:04:51 2022-10-25 21:04:51
# 3793 2022-11-18 07:50:44 2022-10-25 03:40:16 2022-11-21 18:04:58
# 3794 2022-10-25 22:33:12 2022-10-28 12:36:35 2022-10-28 12:36:35
# 3795 2022-11-22 10:42:15 2022-10-31 19:59:47 2022-11-17 09:00:33
#
#          reviewer4_cdate    reviewer4_tmdate  reviewer1_length  \
# 0    2022-11-03 08:08:39 2022-12-14 03:46:36            3318.0
# 1                    NaT                 NaT            5035.0
# 2    2022-10-27 20:14:54 2022-10-27 20:14:54            4181.0
# 3    2022-10-27 22:09:32 2022-10-27 22:09:32            4834.0
# 4    2022-10-29 20:23:57 2022-10-29 20:23:57            3875.0
# ...                  ...                 ...               ...
# 3791                 NaT                 NaT            4056.0
# 3792 2022-10-27 21:23:15 2022-10-27 21:28:42            7448.0
# 3793 2022-10-25 14:45:10 2022-10-25 14:45:10            2645.0
# 3794 2022-11-01 08:09:25 2022-11-01 08:09:25            1486.0
# 3795                 NaT                 NaT            3407.0
#
#       reviewer2_length  reviewer3_length  reviewer4_length  paper_info_length
# 0               3517.0            1776.0            3345.0              960.0
# 1               5064.0            2984.0               0.0             1259.0
# 2               5008.0            3123.0            2419.0             1205.0
# 3               1820.0            2630.0            5561.0             1418.0
# 4               2347.0            3831.0            3200.0             1479.0
# ...                ...               ...               ...                ...
# 3791            2519.0            3055.0               0.0             1561.0
# 3792            5884.0            2250.0            4645.0             1335.0
# 3793            3734.0            4713.0            2808.0             1672.0
# 3794            2535.0            2383.0            4767.0             2053.0
# 3795            4056.0            5469.0               0.0             1377.0
#
# [3796 rows x 42 columns]

# %%
df.dtypes
# Out:
# title                                                   object
# keywords                                                object
# cdate                                           datetime64[ns]
# tmdate                                          datetime64[ns]
# decision_boolean                                          bool
# reviewer1_flag_for_ethics_review                          bool
# reviewer2_flag_for_ethics_review                          bool
# reviewer3_flag_for_ethics_review                        object
# reviewer4_flag_for_ethics_review                        object
# reviewer1_recommendation                                 int64
# reviewer1_confidence                                     int64
# reviewer1_correctness                                    int64
# reviewer1_technical_novelty_and_significance             int64
# reviewer1_empirical_novelty_and_significance           float64
# reviewer2_recommendation                                 int64
# reviewer2_confidence                                     int64
# reviewer2_correctness                                    int64
# reviewer2_technical_novelty_and_significance             int64
# reviewer2_empirical_novelty_and_significance           float64
# reviewer3_recommendation                               float64
# reviewer3_confidence                                   float64
# reviewer3_correctness                                  float64
# reviewer3_technical_novelty_and_significance           float64
# reviewer3_empirical_novelty_and_significance           float64
# reviewer4_recommendation                               float64
# reviewer4_confidence                                   float64
# reviewer4_correctness                                  float64
# reviewer4_technical_novelty_and_significance           float64
# reviewer4_empirical_novelty_and_significance           float64
# reviewer1_cdate                                 datetime64[ns]
# reviewer1_tmdate                                datetime64[ns]
# reviewer2_cdate                                 datetime64[ns]
# reviewer2_tmdate                                datetime64[ns]
# reviewer3_cdate                                 datetime64[ns]
# reviewer3_tmdate                                datetime64[ns]
# reviewer4_cdate                                 datetime64[ns]
# reviewer4_tmdate                                datetime64[ns]
# reviewer1_length                                       float64
# reviewer2_length                                       float64
# reviewer3_length                                       float64
# reviewer4_length                                       float64
# paper_info_length                                      float64
# dtype: object

# %%
reviewer1_cols = [col for col in df.columns if col.startswith('reviewer1')]
df_reviewer1 = df[reviewer1_cols]
df_reviewer1
# Out:
#       reviewer1_flag_for_ethics_review  reviewer1_recommendation  \
# 0                                False                         6
# 1                                False                         3
# 2                                False                         5
# 3                                False                         8
# 4                                False                         3
# ...                                ...                       ...
# 3791                             False                         3
# 3792                             False                         1
# 3793                             False                         6
# 3794                             False                         6
# 3795                             False                         6
#
#       reviewer1_confidence  reviewer1_correctness  \
# 0                        4                      2
# 1                        4                      2
# 2                        4                      3
# 3                        4                      3
# 4                        4                      3
# ...                    ...                    ...
# 3791                     4                      3
# 3792                     4                      1
# 3793                     3                      4
# 3794                     4                      4
# 3795                     4                      3
#
#       reviewer1_technical_novelty_and_significance  \
# 0                                                3
# 1                                                2
# 2                                                3
# 3                                                3
# 4                                                2
# ...                                            ...
# 3791                                             3
# 3792                                             3
# 3793                                             2
# 3794                                             3
# 3795                                             3
#
#       reviewer1_empirical_novelty_and_significance     reviewer1_cdate  \
# 0                                              2.0 2022-10-20 09:40:48
# 1                                              2.0 2022-10-20 13:11:43
# 2                                              2.0 2022-10-24 09:15:54
# 3                                              NaN 2022-10-21 20:21:21
# 4                                              2.0 2022-10-16 18:53:54
# ...                                            ...                 ...
# 3791                                           NaN 2022-10-13 21:40:26
# 3792                                           NaN 2022-10-17 18:44:23
# 3793                                           2.0 2022-10-21 11:20:52
# 3794                                           3.0 2022-10-24 19:12:59
# 3795                                           3.0 2022-10-17 10:38:33
#
#         reviewer1_tmdate  reviewer1_length
# 0    2022-11-23 10:36:28            3318.0
# 1    2022-10-20 13:11:43            5035.0
# 2    2022-10-24 09:15:54            4181.0
# 3    2022-11-27 18:11:29            4834.0
# 4    2022-10-16 18:53:54            3875.0
# ...                  ...               ...
# 3791 2022-10-13 21:40:26            4056.0
# 3792 2022-10-24 07:56:21            7448.0
# 3793 2022-11-21 08:00:37            2645.0
# 3794 2022-11-21 10:28:14            1486.0
# 3795 2022-10-17 17:06:08            3407.0
#
# [3796 rows x 9 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is the DataFrame containing your data

# Calculate the correlation matrix
correlation_matrix = df.corr(numeric_only=True)


# Plot the correlation matrix using a heatmap
plt.figure(figsize=(12, 10))
ax = sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', cbar=True)

# Flip the y-axis
ax.invert_yaxis()

plt.title("Correlation Matrix of Numerical Features")
plt.show()
